# %% [markdown]
# # Imports

# %%
# %cd ../..
# %pwd
# Out:
# /home/sm/repos/KBAsr
# '/home/sm/repos/KBAsr'

# %%
import pickle
import random
import shutil 
import codecs
from functools import partial
from os.path import join

import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import numpy as np
import logging

from utils.loadfile import *
from utils.phonemes import *
from utils.preprocess import *
from utils.evaluate import *
from utils.seqmatch import *
from utils.experiment_helpers import *
from utils.main import *
from utils.asr_models import *

from google_kb_z_speaker.main import *
from google_kb_z_speaker.experiments import *
from google_kb_z_speaker.preprocessing import *
from google_kb_z_speaker.main import *

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
blocks("Hello there my nme Nikos", "Hello there my name Nikos")
# Out:
# ([('Hello there my', 'Hello there my'), ('nme', 'name'), ('Nikos', 'Nikos')],
#  [1])

# %% [markdown]
# # Text processing

# %%
def convert_iso_to_utf(sourceFileName):
    BLOCKSIZE = 1048576  # or some other, desired size in bytes
    with codecs.open(sourceFileName, "r", "ISO-8859-1") as sourceFile:
        with codecs.open(sourceFileName + ".converted", "w", "utf-8") as targetFile:
            while True:
                contents = sourceFile.read(BLOCKSIZE)
                if not contents:
                    break
                targetFile.write(contents)
    shutil.move(sourceFileName + ".converted", sourceFileName)

# %%
read_speech_dir = "data/maggan_read"
dialogue_speech_dir = "data/maggan_dialogue"
curr_speech_dir = dialogue_speech_dir
speech_type = os.path.basename(curr_speech_dir)

# Clean previous output
shutil.rmtree(os.path.join("output", speech_type), ignore_errors=True)
shutil.rmtree(os.path.join("transcriptions", speech_type), ignore_errors=True)
os.makedirs(os.path.join("output", speech_type))
os.makedirs(os.path.join("transcriptions", speech_type))

# %%
speaker_paths = [ os.path.join(curr_speech_dir, x) 
                 for x in os.listdir(curr_speech_dir) if x.startswith("z")]
speaker_paths
# Out:
# ['data/maggan_dialogue/z29',
#  'data/maggan_dialogue/z28',
#  'data/maggan_dialogue/z21',
#  'data/maggan_dialogue/z20']

# %%
# !file data/maggan_dialogue/z*/* | grep "correct"
# Out:
# data/maggan_dialogue/z20/z20.correct:   ISO-8859 text, with CRLF line terminators
# data/maggan_dialogue/z21/z21.correct:   ISO-8859 text, with CRLF line terminators
# data/maggan_dialogue/z28/z28.correct:   ISO-8859 text, with CRLF line terminators
# data/maggan_dialogue/z29/z29.correct:   ISO-8859 text, with CRLF line terminators

# %%
# Copy files from /data/ to output dir and convert to UTF8
for sp in speaker_paths:
    for x in os.listdir(sp):
        if "google" in x:
            shutil.copy(os.path.join(sp,x), os.path.join("output",speech_type,x))
            if speech_type == "maggan_dialogue":
                convert_iso_to_utf( os.path.join("output",speech_type,x))
        if "correct" in x:
            shutil.copy(os.path.join(sp,x), os.path.join("output",speech_type,x))
            convert_iso_to_utf( os.path.join("output",speech_type,x))
# Out:
# 'output/maggan_dialogue/z29.correct'
# 'output/maggan_dialogue/z29.googleasr'
# 'output/maggan_dialogue/z28.googleasr'
# 'output/maggan_dialogue/z28.correct'
# 'output/maggan_dialogue/z21.correct'
# 'output/maggan_dialogue/z21.googleasr'
# 'output/maggan_dialogue/z20.googleasr'
# 'output/maggan_dialogue/z20.correct'

# %%
# !file ./output/maggan_read/* | grep ISO

# %%
iso_speakers = ["z16", "z17", "z18", "z22", "z23", "z25", "z26", "z3", "z5", "z6", "z7"]

# %%
# Some maggan read files are iso-8859 # Not idempotent
if speech_type == "maggan_read":
    for filename in os.listdir(os.path.join("output", speech_type)):
        for speaker in iso_speakers:
            if speaker in filename and "google" in filename:
                print(f"Converting {speaker} in filename {filename}")
                convert_iso_to_utf( os.path.join("output",speech_type,filename))

# %% [markdown]
# ## Transcribe directory of speakers

# %%
ASR_MODELS
# Out:
# ['KBLab/wav2vec2-large-voxrex-swedish',
#  'birgermoell/lm-swedish',
#  'viktor-enzell/wav2vec2-large-voxrex-swedish-4gram']

# %%
for d in tqdm(speaker_paths):
    speaker_name = os.path.basename(d)
    output_path = os.path.join("output",speech_type, speaker_name + ".kb")
    print(f"Transcribing {speaker_name} with output path {output_path}")
    transcribe_from_dir_path(d, output_path, "cpu", ASR_MODELS[2])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2022-06-07 12:59:17,143.143 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# Transcribing z29 with output path output/maggan_dialogue/z29.kb
# 2022-06-07 12:59:17,892.892 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/config.json HTTP/1.1" 200 0
# 2022-06-07 12:59:17,905.905 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:18,609.609 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# 2022-06-07 12:59:29,061.61 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:29,874.874 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2022-06-07 12:59:29,886.886 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:30,693.693 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/vocab.json HTTP/1.1" 200 0
# 2022-06-07 12:59:30,701.701 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:31,410.410 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2022-06-07 12:59:31,418.418 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:32,127.127 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/added_tokens.json HTTP/1.1" 404 0
# 2022-06-07 12:59:32,131.131 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:32,946.946 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/main/special_tokens_map.json HTTP/1.1" 200 0
# 2022-06-07 12:59:32,958.958 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:33,663.663 DEBUG connectionpool:  https://huggingface.co:443 "GET /api/models/viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/revision/main HTTP/1.1" 200 2129
# 2022-06-07 12:59:33,672.672 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:34,482.482 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/3cafa40b3433cf9d1b3b2b65c37c48541f57d1a8/alphabet.json HTTP/1.1" 200 0
# 2022-06-07 12:59:34,493.493 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:35,199.199 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/3cafa40b3433cf9d1b3b2b65c37c48541f57d1a8/language_model/4gram.bin HTTP/1.1" 302 0
# 2022-06-07 12:59:35,212.212 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:35,724.724 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/3cafa40b3433cf9d1b3b2b65c37c48541f57d1a8/language_model/attrs.json HTTP/1.1" 200 0
# 2022-06-07 12:59:35,736.736 DEBUG connectionpool:  Starting new HTTPS connection (1): huggingface.co:443
# 2022-06-07 12:59:36,300.300 DEBUG connectionpool:  https://huggingface.co:443 "HEAD /viktor-enzell/wav2vec2-large-voxrex-swedish-4gram/resolve/3cafa40b3433cf9d1b3b2b65c37c48541f57d1a8/language_model/unigrams.txt HTTP/1.1" 200 0
#   0%|          | 0/319 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
#       3 output_path = os.path.join("output",speech_type, speaker_name + ".kb")
#       4 print(f"Transcribing {speaker_name} with output path {output_path}")
# ----> 5 transcribe_from_dir_path(d, output_path, "cpu", ASR_MODELS[2])
#
# File ~/repos/KBAsr/utils/asr_models.py:45, in transcribe_from_dir_path(dir, output_file, device, model_id)
#      42         complete_filename = os.path.join(dir, filename)
#      43         filenames.append(complete_filename)
# ---> 45 transcriptions = transcriber.transcribe(filenames)
#      47 ret_lines = []
#      48 for k, v in zip(filenames, transcriptions):
#
# File ~/repos/KBAsr/utils/asr_models.py:95, in FileTranscriber.transcribe(self, audiopaths)
#      93 def transcribe(self, audiopaths : Union[str, List[str]]):
#      94     waveforms = self._wavify_and_resample(audiopaths)
# ---> 95     return self.transcriber.transcribe(waveforms)
#
# File ~/repos/KBAsr/utils/asr_models.py:148, in TranscriberLM.transcribe(self, waveforms)
#     145 inputs = self.processor(waveforms, sampling_rate=self.sample_rate,
#     146                         return_tensors="pt", padding=True).to(self.device)
#     147 with torch.no_grad():
# --> 148     logits = self.model(**inputs).logits
#     150 transcriptions = self.processor.batch_decode(logits.cpu().numpy()).text
#     151 transcriptions = [x.lower() for x in transcriptions]
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:1716, in Wav2Vec2ForCTC.forward(self, input_values, attention_mask, output_attentions, output_hidden_states, return_dict, labels)
#    1706 r"""
#    1707 labels (`torch.LongTensor` of shape `(batch_size, target_length)`, *optional*):
#    1708     Labels for connectionist temporal classification. Note that `target_length` has to be smaller or equal to
#    (...)
#    1711     config.vocab_size - 1]`.
#    1712 """
#    1714 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1716 outputs = self.wav2vec2(
#    1717     input_values,
#    1718     attention_mask=attention_mask,
#    1719     output_attentions=output_attentions,
#    1720     output_hidden_states=output_hidden_states,
#    1721     return_dict=return_dict,
#    1722 )
#    1724 hidden_states = outputs[0]
#    1725 hidden_states = self.dropout(hidden_states)
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:1347, in Wav2Vec2Model.forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1342 output_hidden_states = (
#    1343     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1344 )
#    1345 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1347 extract_features = self.feature_extractor(input_values)
#    1348 extract_features = extract_features.transpose(1, 2)
#    1350 if attention_mask is not None:
#    1351     # compute reduced attention_mask corresponding to feature vectors
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:515, in Wav2Vec2FeatureEncoder.forward(self, input_values)
#     510         hidden_states = torch.utils.checkpoint.checkpoint(
#     511             create_custom_forward(conv_layer),
#     512             hidden_states,
#     513         )
#     514     else:
# --> 515         hidden_states = conv_layer(hidden_states)
#     517 return hidden_states
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:387, in Wav2Vec2LayerNormConvLayer.forward(self, hidden_states)
#     386 def forward(self, hidden_states):
# --> 387     hidden_states = self.conv(hidden_states)
#     389     hidden_states = hidden_states.transpose(-2, -1)
#     390     hidden_states = self.layer_norm(hidden_states)
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/conv.py:302, in Conv1d.forward(self, input)
#     301 def forward(self, input: Tensor) -> Tensor:
# --> 302     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/repos/KBAsr/venv/lib/python3.8/site-packages/torch/nn/modules/conv.py:298, in Conv1d._conv_forward(self, input, weight, bias)
#     294 if self.padding_mode != 'zeros':
#     295     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     296                     weight, bias, self.stride,
#     297                     _single(0), self.dilation, self.groups)
# --> 298 return F.conv1d(input, weight, bias, self.stride,
#     299                 self.padding, self.dilation, self.groups)
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:73] . DefaultCPUAllocator: can't allocate memory: you tried to allocate 20473026560 bytes. Error code 12 (Cannot allocate memory)

# %%
# Copy output dir to transcriptions 
from distutils.dir_util import copy_tree
copy_tree(f"./output/{speech_type}", f"./transcriptions/{speech_type}")

# %%
# !ls transcriptions/maggan_dialogue

# %% [markdown]
# ## Get bunches

# %%
bunches = get_bunches("transcriptions", speechType="maggan_dialogue")

# %%
len(bunches["correct"])

# %%
bunch_list = [{k: bunches[k][i] for k in bunches} for i in range(len([x for x in bunches.values()][0]))]

# %%
bunch_list[2:5]

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Ensemble evaluation
#
# Here we evaluate the first ensemble created between Google and KB and perform a grid search to find the optimal phonemizer and ratio threshold

# %%
# Get ensemble wer only on non agreement between kb and google 
def ensemble_wer_on_non_agreement(bunches, phonemizer, ratio_threshold, use_phonemizer):
    bunch_list = [{k: bunches[k][i] for k in bunches} for i in range(len([x for x in bunches.values()][0]))]
    # Filter on non agreement
    #bunch_list = [x for x in bunch_list if x["google"] != x["kb"]]
    #get ensemble outputs
    ensemble_outputs = [get_ensemble_output(bunch, phonemizer, ratio_threshold, use_phonemizer) for bunch in bunch_list]
    # Recreate bunches
    bunches = {k : [x[k] for x in bunch_list] for k in bunch_list[0]}
    
    return {**google_kb_wer(bunches), "ensemble_wer" : wer(bunches["correct"], ensemble_outputs)}
    
ensemble_wer_on_non_agreement(bunches, None, 0.6, False)
# Out:
# {'google_wer': 0.1983669548511047,
#  'kb_wer': 0.13864873519052193,
#  'ensemble_wer': 0.13544668587896252}

# %%
experiment = ensemble
kwargs = {
    "bunches" : bunches,
    "use_phonemizer" : False,
    "save_ensemble_output" : False
}
args = [
    [ensemble],
    [5],
    [
        "./models/deep-phonemizer-se.pt",
        #"./models/DeepPhon/winhome/Downloads/DeepPhon_to_send/best_model.pt",
        #"./models/DeepPhon/winhome/Downloads/DeepPhon_to_send/model_step_40k.pt"
    ],
    [0.6]
]
# Convert phonemizer paths to phonemizers
phoneme_dict = read_phoneme_dict("models/stress_lex_mtm.txt")
args[2] = [ phonemizer_wrapper(init_phonemizer("cuda", x), phoneme_dict=phoneme_dict, include_stress_marks=False, batch_size=300)
           for x in args[2]]
experiment = experiment_repeats
res = grid(experiment,args,kwargs, stub=False)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
{k : f"{v.mean} += {v.std}" for k,v in res[0][1].items()}
# Out:
# {'google_wer': '0.13522388059701493 += 0.0',
#  'kb_wer': '0.08686567164179104 += 0.0',
#  'ensemble-wer': '0.08980099502487562 += 0.0'}

# %%
with open("output/ensemble_eval", "rb") as f:
    res = pickle.load(f)

# %%
res[0]
# Out:
# ((<function phonemes.phonemizer_wrapper.<locals>.phonemizer_to_return(texts: Union[str, List[str]], lang)>,
#   0.6),
#  {'google_wer': 0.1983669548511047,
#   'kb_wer': 0.19164265129682997,
#   'ensemble-wer': 0.1525776496958053,
#   'ensemble_outputs': ['ja nu har jag också startat',
#    'ja',
#    'nej det var en gammal veteranmoped',
#    'jå det var väldigt kul det var det',
#    'men du jag tänkte jag tog fram de här fraserna nu',
#    'i min telefon',
#    'man skulle bara kunna läsa även om det blir hur',
#    'hur säger goddag yxskaft som helst kanske man kan läsa dem',
#    'om jag säger hej till exempel så säger du hur står det till så står bredvid ser du dem också',
#    'så gör man det som en liten dialog',
#    'fast det kommer att bli bara rappakalja',
#    'ja det kanske går',
#    'eller kanske oom jag får säger hej hur står det till',
#    'och sen tar du nästa rad med två liksom',
#    'fattar du',
#    'hej hur står det till',
#    'hej hur står det till',
#    'var kanske inte världens bästa idé',
#    'd läget',
#    'tjena',
#    'nej men hej det var längesen',
#    'nå okej',
#    'glömde vi en',
#    'godmorgon',
#    'tack bara bra',
#    'hur är det med dig',
#    'jo det gör nog ingenting',
#    'ja',
#    'ja men i alla fall då så jag mår bra tack hur mår du själv',
#    'hej hej',
#    'detsamma',
#    'ja',
#    'ja hur blir',
#    'ja',
#    'kan du upprepa det hörs väldigt dåligt',
#    'kan du upprepa det hörs väldigt dåligt',
#    'stackars dig',
#    'står de så här eller',
#    'eller pratar du sanning med',
#    '',
#    'men du var o en kvinnlig detektiv',
#    'eller',
#    'jag som egentligen var journalist eller',
#    'ehe nej na',
#    'var de en bra rål fall',
#    'ojdå såg ni alla higår eller',
#    'naja',
#    'nåja',
#    'nej vi har ju vart lite måssiga då',
#    'serier som våra är liksom slut nu',
#    'men det var mer så här',
#    'trädgårdstider',
#    'va ju vårat favorit',
#    'lite halvt töntigt men ändå bra',
#    'och sen var det ju den där snöänglar och',
#    'ja så nu har vi inte riktigt något nytt',
#    'ja men det är svårt det är att vara i takt det håller jag med om',
#    'ja',
#    'kan man no säga',
#    ' sen ve jag håller ju på att lyssna på en bok',
#    'kerstin ekman',
#    'a är vä en',
#    'är det bara två eller är det till och med tre böcker så jag har en kvar sedan',
#    'sista rompan heter den här i alla fall',
#    'ja just det det är nog tre böcker jag',
#    'jag är på slutet på den andra',
#    'det är ganska maffig maffia böcker',
#    'ja',
#    'nä',
#    'mycket sådär norrland och timrå',
#    '',
#    'trädgårdsland',
#    'a',
#    'men det var inte illa',
#    'jag satte potatis igår men det andra tänkte jag ska sova imorgon',
#    'na här är det nog',
#    'ungefär',
#    'bra nu tror jag',
#    'ja',
#    'så lagade vi växthuset igår också och satte i nya rutor där det behövdes och så',
#    'så det var bra',
#    'nu köpte vi',
#    'och så har vi skrivit a man bara lyfter du den trasiga ',
#    'ska det var lite gummilist på och sen så lägger man i dem och',
#    'det är inte så svårt',
#    'na',
#    'oj då',
#    'nej',
#    'oj',
#    'men den är väldigt hållbar då låter det som',
#    'ja',
#    'oj då',
#    'ja',
#    'men du har jag berättat om grannarnas garageprojekt',
#    'blir inte full i skratt för vi var så himla på krigsstigen första liksom',
#    'höll på att planera hur  vi skulle skriva en överklagan och yttrande och sådär',
#    'ja vi drog på med allt möjligt liksom de och de och katastrof och',
#    'och sen har vi varit efter bara ja men alltså det är kanske inte är så illa',
#    'så blir rett så bra det där och',
#    'jd gar väll detdär så myket',
#    'meh till slut blev det världens kortaste och och lite sådär',
#    'a grannarna ska bygga ett väldigt stort garage och det kommer ',
#    'hur påverkar vår utsikt på vårt ljusinsläpp hejdå',
#    'lite så blev det mer',
#    'och så har jag dessutom varit o prata med grannen och sagt att',
#    'man vill ju inte att jag ska vinna surdeg och det där ja och liksom',
#    'så vi får se',
#    'vad som blir nästa drag',
#    'men jag tror inte vi har ett skit att säga till om igentligen',
#    'faktiskt',
#    'nej inte åt vårt hal nej precis så så då kan vi ta ner a',
#    'mat har ju varit så mån om de är insynsgardin eller',
#    'så nej visst så är det ju',
#    'och så tänker vi att vi kan flytta våran vedboden från den här fina platsen där den står nu',
#    'och ställa liksom mot',
#    'gavel på deras garage',
#    'videt går ju nu ut som en liten udde liksom ut över den här fina griggåkern som',
#    'på baksidan',
#    'den ligger liksom lite upphöjd och så är det en slänt ner till åkern',
#    'och så ser man se här gamla stenrösen och',
#    'och så',
#    'oh då skulle man kunna flytta den och då skulle man kunna ha något jättefint där på den platsen',
#    'jag som till exempel ett litet attefallshus eller ett stort fint orangeri eller',
#    'växthus eller',
#    'man kan ju drömma om vad som helst är',
#    'ja',
#    'det är det faktiskt',
#    'ja',
#    'ja',
#    'men det känns väl ändå skönt att man har sagt till om det som aman alla fall gjort vad man kan för',
#    'utan av varför',
#    'ja',
#    'jaha men du tror att vi ska att inte göra den här inspelningen heller för lång eller',
#    'ja',
#    'det kan vi göra',
#    'ja',
#    'det var lite sådär',
#    'tjt',
#    'nu har ju jag bara ett',
#    'ja men då stänger jag av inspelningen nu',
#    'inspelning nu börjar vi igen',
#    'ha',
#    'yes nu så rullar du inspelningen',
#    'nu kör vi',
#    'ska vi bara babbla på så här eller ska vi',
#    'ta fram parlören och börja',
#    'tala i fraser i olika sinnesstämningar',
#    'ja',
#    'ja',
#    'jag har nästan så här gått och små träna sitter på att säga hej på olika',
#    'olika sätt',
#    'och hur mår du och så där',
#    'hur mår du',
#    'hur mår du',
#    'hur mår du',
#    'hur mår du egentligen',
#    'nej jag vet inte',
#    'eurovision grannen den här lilla grannflickan hos oss som ropar grannarna',
#    'hon kallar oss barför grannen både mig',
#    'hon sa igår att',
#    'ja',
#    'men hon sa att det var',
#    'någon sorts tävling och då trodde jag att hon menar eurovision och då sa hon att det redan var slut eller ja det blev väldigt förvirrat',
#    'men är det alltså final i själva',
#    'eurovision ikväll',
#    'och ett våran tusse med där då',
#    'aha för final för mig då låter det  som att då är det typ två kvar men då är det ändå massor med låtar',
#    'och det kommer att ta hela natten',
#    'ja',
#    'ja jag kommer',
#    'ja kanske kommer jag inte att titta men jag hejar ändå på tusse',
#    'det vore roligt det är en bra låt',
#    'ja men jag fick lite dåligt samvete när vi var i göteborg',
#    'och jag liksom hejade på att vi skulle se det så tog det hela kvällen',
#    'och det är så mycket trams och reklam',
#    'och sen förlorar du än den vi hejade på',
#    'så det var lite dystert',
#    'ja',
#    'ja',
#    'men tina sa ju det att hon skrev att',
#    'det spelar ingen roll att han inte vann bara jag fick se honom dansa',
#    'så hon var lycklig ändå tror jag',
#    'ne nej ',
#    'jag tycker nog bara själva det och se dem dansa är så roligt och sedan blir jag ju väldigt avundsjuk för jag skulle själv så gärna vilja dansa',
#    'så där med nån',
#    'är anisk till exempel',
#    'ja absolut',
#    'vem',
#    'aha',
#    'ja nu kan vi ju försöka ta igen den här veckans kryss faktiskt',
#    'var det något några sån här gamla visor frågor för mig då',
#    'ja då var det kanske så att vi',
#    'ja men det kanske är matskan',
#    'ja där behöver vi er',
#    'de är vi uörsliga på',
#    '',
#    'det kan vara värt ett försök',
#    'ja jag skulle gärna vilja ha gallerivju',
#    'nu ska vi se',
#    'det finns ett läge som heter',
#    'ihop läge',
#    'stort galleri',
#    'nu tycker jag på stort galleri då blev det ingen skillnad',
#    'joman nu',
#    ' oj nu blev jag jätte stor och nu ska jag flytta den lite så',
#    'nu är vi lite mer',
#    'varsin suddig',
#    'ruta',
#    'jag tror jag valde gallery view',
#    'ja det blev bättre',
#    'jaha',
#    'ja jag tänkte häromdagen på också när ni ska komma hit och hälsa på egentligen och vad ni ska sova allihop',
#    'ja',
#    'ja',
#    'ja',
#    'vi kunde ju sätta upp militärtält i kanske då',
#    'ja',
#    'tror att de skulle få plats på baksidan om man riktigt vill men annars absolut så kan vi ordna så att vi har ju lilla stugan på gården och',
#    'ett gästrum och',
#    'så det går allt',
#    'ja',
#    'ja det var det ju pratat om förut iallafall',
#    'vi får väl se',
#    'men',
#    'ja',
#    'ja',
#    'ja',
#    'ja',
#    'och det var',
#    'helgen vecka tjugosju va',
#    'eller',
#    'vi undra om det kan ha vart så att det i så fall är',
#    'när min semester börjar',
#    'nej det var kanske på slutet precis',
#    'nej',
#    'jaha',
#    'där jag tina till sala',
#    'då',
#    'metrettio',
#    'ja då är det  väl typ  någonstans mitt i semestern då',
#    ' jag vetinte jag har skrivit i semester här i flera',
#    'var väldigt för jag har semester',
#    'ja',
#    'nä vet du vad jag har ju inte det',
#    'och nu har det faktiskt kommit ut en tjänst på socialtjänsten',
#    'men då är det en kombination av familjebehandlare och samordnare',
#    'och det de samordnade elen',
#    'eja nog inte ja det ska man väl på något vis',
#    'ha någ lite så här ledande funktioner',
#    'aja vi  det är fem fyra dar kanske kvar st att söka till den',
#    'jaha nu kommer det upp någon ruta här i min dator nu ska vi se vad som händer',
#    'i mora',
#    'ja',
#    'nej familj familjebehandlare',
#    'och samordnare',
#    'ja',
#    'men',
#    'ja vi får väl se',
#    'och så kan jag också tänka att jag kan sätta ett nytt ett års mål',
#    'så att jag blir legitimerad sjukvårdskurator',
#    'det blir man nämligen om man jobbar på bup i två år',
#    'det låter väl fint',
#    'vad man nu ska med det till',
#    'nä det blir ju på ett vis blir det ju roligare och roligare',
#    'och på ett vis är somliga saker skittråkigt men',
#    'ja vi får se',
#    'ja det vore ju kanske',
#    'faktiskt lite tid att göra det',
#    'och om man inte är särskilt liksom',
#    'angelägen om att få et eller vad ska man säga man tar inte till vilket pris som helst',
#    'då kan man ju faktiskt söka och tala om så att jag',
#    'jag är ganska intresserad av själva familjebehandlare delen men de andra är det sådär lika intressant',
#    'och så kan man ja även om det gör att man inte får jobbet så',
#    'så är det  ingen katastrof',
#    'men det är också så där att nu när man är klar med min utbildning jag skulle jag också kunna jobba kvar ett tag och',
#    'liksom verkligen få jobba med just precis det fanns det skulle jag få där också i och för sig',
#    'ja',
#    'ja vi får se  och så kan man ju ha',
#    'skulle jag kunna ha lite samtal med min nuvarande chef och så',
#    'tala om hur man vill ha det och',
#    'om man blir erbjuden ett annat jobb',
#    'ja men jag vill inte hålla på med så mycket byråkratiskt skit',
#    'ja det får de andra',
#    'jag vet inte',
#    'jo',
#    'ja',
#    'ja fast man har också en massa liksom',
#    'att jag kanske har fyrtio stycken på min lista som jag är',
#    'oj då',
#    'ja det verkar vara lite som',
#    'jag undrar om jag ska ha dörren öppen eller',
#    'hör du mig igen eller',
#    'ja nu har  alla fall dörren öppen men',
#    'ja',
#    'nu ska vi se det som någon liten varningstriangel där på',
#    'potims',
#    'ja jag vet inte jag ser att det är en liten triangel där vad händer om jag trycker på den',
#    'oj',
#    'nej du försvann inte nu va',
#    'du är där',
#    'klicka här för att delta i mötet jag är redan med i mötet',
#    'men var är du nu',
#    'jajag seer inte dig längre du ska se där',
#    'a den här tekniken',
#    'nej nu ser jag bara mitt eget se',
#    'gör fattar inte vad som händer nu',
#    'här nu nu ser jag dig u ser jag dig',
#    'men det kommer upp en ruta liksom framför dig men du stänger av den nu då',
#    'men hackar jag lite fortfarande eller',
#    'ja',
#    'ja ja',
#    'men',
#    'borde vi nu också prata om saker som',
#    'tina skulle prata om',
#    'ja jag har frusit',
#    'och jag har frusit ien björksav i små isbitar till tina',
#    'då ska hon bli frisk om hon dricker de',
#    'lätt laxerande',
#    'nej det vet jag inte',
#    'ja',
#    'det är det nog tror jag',
#    'ja',
#    'så är det nog',
#    'har jag en större huvudtaget',
#    'jo',
#    'nej det var aldrig fest i fältbiologerna',
#    'ja men var det inte särskilt för barn då att de var någon sorts barnugglel',
#    'för små barn ugglor',
#    'nej men det var väl intresserad av oss',
#    'ja alltså jag minns ju ingenting av såna där saker nu',
#    'piper i mina hörlurar vilket betyder att de håller på att ladda ur',
#    'och laddsladden till dem',
#    'den är ungefär',
#    'bara',
#    'femton centimeter',
#    'så jag undrar om jag',
#    'dessutom saknas en liten bit',
#    'om jag nu sätter i den på laddning',
#    'gud vad avancerat',
#    'ja',
#    'ja men nu',
#    'vad hände nu',
#    'nej vad bra det har varit så mycket bättre nu ska vi se mer',
#    'jag ska bara försöka utan och strypa om hitta laddhålet',
#    '',
#    'oj oj oj',
#    'så',
#    'nu ska vi se och så har jag en annan dator här nu så nu sitter jag i',
#    'hörluren på laddning men jag borde sätta den i väggen men jag kan inte sitta vid vägg',
#    'jag provar och sätt den i andra då',
#    'nu får vi se',
#    'om den laddar via dator',
#    'ja jag hör dig hör du mig',
#    'nhe',
#    'jaha',
#    'men ja omfältpluggrna jag minns ingenting av det där',
#    'faktiskt',
#    'tyvärr',
#    'ja',
#    'men det är klart att jag kanske dina behöver ett litet vokabulär av åtminstonde blåsippa vitsippa',
#    'snödroppe',
#    'ja',
#    'lavar',
#    'mycket ritza kanske till och med',
#    'mycket ritza heter det så',
#    'det är väl så här svamparnas rotsystem',
#    ' ja det kanske det är ja nu tycker jag vi går vidare till ett annat ämne',
#    'då hoppar vi raskt vidare',
#    'nej det har jag inte faktiskt det var  ett antal dagar sedan  jag pratar med honom',
#    'hur är det med honom då',
#    'men kan inte köpa ett par nya då',
#    'för att byta guldknappar eler',
#    'men vad pinsamt',
#    'nä det först',
#    'nej',
#    'oj då',
#    'ja',
#    'men han kanske borde',
#    'att vi borde hjälpa honom shoppa lite kläder då',
#    'har han inte några sär joggingbyxor',
#    'skulle inte det var skönt',
#    'jhan har ju haft ett par de är kanske i vad någn san ä blå jagföhan har den sär blå',
#    'collegetröja och',
#    'ja',
#    'nej men det behövs kanske en liten shoppingtur då',
#    'jag funderar lite på hur',
#    'nästa helg',
#    'om man skulle åkt ner över på något vis',
#    'men jag har inte bestämt något än men jag ska ändå till falun på fredag morgon',
#    'ja men och jag tänker också om man skulle ha det kanske man skulle behöva hälsa på pappa ja',
#    'men också åka till vad',
#    'och',
#    'och helst skulle man också fälla några björkar där',
#    'ja',
#    'ja då behöver',
#    'då behöver vi ännu mer fälla träd',
#    'jag ska bearbeta mats lite också jag tycker han ska åka med nämligen',
#    'om ni kommer så kanske till och med axel skulle kunna följa med',
#    'jaha',
#    'ja',
#    'nej',
#    'och bryggan då har den ligger den helt på svaj',
#    'naja',
#    'just det',
#    'ja ja',
#    'ända ner vid vattnet',
#    'nej det gör man no kanske inte',
#    'men alltså precis rakt mittemot',
#    'jaha',
#    'ja ja men det är väl bara',
#    'en tidsfråga',
#    'jag vill gammal skog runt hela',
#    'sjön',
#    '',
#    'ja',
#    'vi',
#    'ja ja',
#    'ja',
#    'kanske det är mycket sås och falukorv och',
#    'och så här feta grejer',
#    'ja just det och agilityg',
#    'så inte det försvinner tänker jag',
#    'ja',
#    'det är ju kan man ju undra',
#    'vad spännande om man skulle kunna lära en sig mekaniska röster sjunga',
#    'fantastiskt',
#    'ja',
#    'ja',
#    'hon sjöng väl för sina barn iallafall när de var små',
#    'ja alltså det där fattar man inte när man tänker efter hur det där gick till',
#    'finns det finns det på film också',
#    'ni har inte det på film',
#    'ea',
#    'nej det pratar vi ju om också på mitt vårat bröllop att vi lyckligtvis inte har några bilder',
#    'ja precis som vi',
#    'nej',
#    'nej ingen av oss fyra barn har väl något tjusigt bröllopsfoto',
#    'tina per gick väl och köpte pizza vara och gick till tingsrätten typ',
#    'och magnus och grilla det kanske var lite fint de var väl på sätra brunn något',
#    'bröllopsmiddag med mammorna',
#    'justet',
#    'men det var något mer',
#    'pratar vi om nyss',
#    'åjda',
#    'ja det där är ju också projekt för oss här då',
#    'röja ut huset från det vissa möbler är så svårt att göra sig av mig',
#    'ill exempel den där',
#    'lite gulaktig byrån som är kvar ända från när vi var små',
#    'liksom',
#    'ja det är tre lådor i den',
#    'ja',
#    'du vill inte ha den eller',
#    'eller behöver vi den i vad eller',
#    'åh vad bra',
#    'men tog du bort någonting också',
#    'ja',
#    'eller kanske en gul liten byrå',
#    'det känns som att så mormorvivis vävstol det är inget annat än',
#    'en upp eldning som',
#    'alltså det är helt värdelös produkt i dagens läge',
#    'inte ens kattunge kursen vill ha den',
#    'gratis',
#    'funderar kan man göra något roligt konstverk av den eller kan man göra en',
#    'ja',
#    'jagär där faktiskt med allt med stickning och ostr',
#    'alltså väva nej över min döda kropp att jag kommer hålla på med det',
#    'det blir ju inte ens någonting vettigt av det',
#    'det går bättre utan vävstol',
#    'ja',
#    'ja',
#    'de kan jag säga att jag inte gör',
#    'men däremot så var vi faktiskt förbi och',
#    'huset vi bodde förut',
#    'för vi skulle sälja gräsklipparen som stod kvar där',
#    'och han',
#    ' det är ju ett par som har flyttat in där och han har ju absolut liksom adhd gånger fyra',
#    'det är som fortsatt liksom och pratar och pratar och pratar och pratar',
#    'och hon är lite mer sådär sansad o',
#    'verseende med honom och ta hand om honom',
#    'men de hade ju liksom',
#    'bar jag tänker var otroligt lite vi gjorde där',
#    'och sen nu bara på hur länge har de bott där',
#    'några månader så har de liksom',
#    'målat om nästan överallt målat om nästan alla fönster slagit ut väggen mellan köket och vardagsrummet rivit ut hela köksinredningen och satt i nytt',
#    'ja alltså nu var det  väldigt stökigt de har ju två barn och det var liksom mycket grejer så men',
#    'men absolut jag ljust och fint och så ska de bygga ut hela balkongen smala delen på balkongen ska den liksom flytta ut två meter',
#    'så att det blir',
#    'stor plats o ska de sätta glas räcke och de',
#    'jag håller på',
#    'men det kändes ändå rätt skönt för jag kände mig inte ett dugg',
#    'liksom avundsjuk att jag r',
#    'nej',
#    'det där är jag lämnat',
#    'ganska kul att de',
#    'ja',
#    'ja men så är det väl också så är  som',
#    'som att så att han',
#    'skulle vi ha gjort nego då johan sådär då tänker ju han på sånt där att väggarna ska vara bra isolera du att  liksom',
#    'han skulle aldrig börja måla invändigt innan han vetat',
#    't är en bra isolering i väggarna och och då blir det ju liksom ingenting för då',
#    'nej ska man göra det ska man göra det grundligt liksom det är ju mer hans',
#    'ja',
#    'ja',
#    '',
#    'jaha',
#    'men nu ska vi tänka här',
#    'man glömmer verkligen bort vad det är vi håller på med för språkprojekt här egentligen vi bara babbla på',
#    'ji har väl inte sagt några pinsamma hemlisar',
#    'men tänkte min också',
#    'ja',
#    'men då stänger vi av inspelningen nu då',
#    'och så ser jag dig där jag fattar fortfarande inte varför jag inte har internet i',
#    'ja det är micron det är wilma som ska fika vad ska du värma för något',
#    'jaha',
#    'värme kaffe',
#    'kaffe i micron',
#    'ja',
#    'jag har faktiskt gott om småkakor för en gång skull',
#    'fem två dieten består nu av att jag fem gånger om dagen äter jättegod mat och två gånger om daen så fika',
#    'jättemycket kaffe präat',
#    'det är den nya sommar fem två',
#    'ja och så har jag',
#    'jag bakade småkakor förra',
#    'helgen var det väl för då hade vi vänster möte hemma hos mig i trädgården',
#    'då konka du alla trädgårdsmöblerna till baksidan på huset för övrigt förrådet så varmt',
#    'jag vaknade ja det kan jag ju installera om då ja jag bakade chokladsnittar',
#    'penslade med ägg och strö med hackade nötter',
#    'och så bakade jag bondkakor',
#    'de gör man ju en deg du vet och sen så rullar man den till rullar och så är det mandel i och så skärman dem i skivor och',
#    'h grädda dem',
#    'ja men så gjorde jag också',
#    'typ hallongrottor fast jag hade hjortrongrottor',
#    'då gör man en deg och sen så',
#    'rullar man den till små kulor och så lägger man dem i',
#    'bullformar och så trycker man ett hål',
#    'i mitten och så lägger man i sylt',
#    'ja nej det ska ju hade inget jag hittar inte hallonsylt den så då fick det bli',
#    'fick det bli så oj nu har mina hönor rymt',
#    'ja',
#    'ha nu blir det kanske s actionfilm',
#    'de är rakt på väg ner mot grönsakslandet faktiskt',
#    'nej det akta han sig nog för',
#    'men vi ska se här om jag måste kanske',
#    'gud vad jobbigt med hela inspelningsapparat än jag tar med den',
#    'men då kommer du att försvinna',
#    'då måste jag ta med mobilen',
#    'och inspelningsapparat en',
#    'och så fastnar sladden i storleken',
#    'ja nu är det liksom',
#    'fast stängslet stå kvar och allt',
#    'nähä nu ska vi se',
#    'ja när ska ni komma och hälsa på då',
#    'precis',
#    'nu ska vi se nu ska vi sitta i laddningen på mobilen',
#    'sådär',
#    'hönorna inne och',
#    'allt väl igen',
#    'jag har ringde till mig igår morse och då då lät han så där',
#    'han måste ha vaknat precis och bara ringt',
#    'ja jag skulle bara det så vill han liksom ha lite ordning och reda i huvudet förå',
#    'vad han är nu var han ju tillbaka där på där han booorr igen och han hade varit någon annanstans några dagar då så där',
#    'nämen oj då',
#    'ja',
#    'ja usch vad krångligt det kan bli',
#    'men det trodde jag inte riktigt liksom har jag inte förväntat riktigt att han skulle bli sådär',
#    'förvirrad',
#    'men det känns som att det inte är',
#    'demens på samma sätt som en mamma utan att det här är mer',
#    'liksom när han är trött han är så slut ibland så han',
#    'eller nyvaken eller har druckit för mycket vin eller',
#    'ja',
#    'ja',
#    'ja',
#    'men det där börjar jag känna igen mig',
#    'ja',
#    'ja verkligen',
#    'jag vet inte de måste faktiskt se ut som om de måste ha flaxat över eti stängslet idag jag har ju satt upp det här',
#    'sär provisoriskt',
#    'nä som inte är jättehögt men',
#    'den har nog kanske flaxat över nu är de här och trampar igen och försöker komma ut tror jag',
#    'f',
#    'ne de är där och tassar i hörnet',
#    'förstår att jag håller på med något annat nu och inte vakta då',
#    'jag ser hur hela nätet gungar',
#    'nej det brukar jag inte',
#    'men då brukar jag inte få vara ute när ingen är hemma här men ja ja',
#    'det är ingen katastrof om de smiter heller',
#    'ja kanske',
#    'nej det enda som är synd är väl om de går ner i grönsakslandet och äter upp det lilla som har kommit upp',
#    'i mitt grönsaksland har jag satt',
#    'mycket potatis faktiskt',
#    'och det var lite på försök för jag hade kvar gammal potatis som har stått i jordkällaren enl matkällan i en hink så den hade ju fått jätte jätte långa groddar',
#    'men jag provade att sätta den iallafall och liksom var rädd om de där grodan som inte skulle gå av',
#    'så det får vi väl se om det lyckas men de  har kommit upp i alla fall',
#    'och så köpte jag lite sättpotatis också av några olika sorter',
#    'så det blev ju halva landet',
#    'sen har jag sagt',
#    'gamla frön som sagt så jag satte tårtor där hade några enstaka kommit upp',
#    'röbetsraden de hade det hade kommit upp en rödbeta',
#    'morötter kommer väl inte strida',
#    'rödbetor med inlagda rödbetor',
#    'kan man göra och sen så tycker jag det är ganska gott och',
#    'äta liksom kokta rödbetor',
#    'oj nu',
#    'frös bilden på dig här',
#    'söker efter nätverk',
#    'det händer nåt här',
#    'men vad är detta nu då',
#    'ja då får jag prata på själv här nu då får du slängde se ut ur tins',
#    'åjar jag',
#    'så säger den söker efter nätverk fast jag redan var inne där',
#    'koppla jag väl upp igen',
#    'hallå',
#    'ha och nu är du med i telefonen istället jag slängdes ut',
#    'ja men jag provar att koppla upp igen',
#    'ja',
#    '',
#    'då ska vi se',
#    'väldigt konstigt jag stänger av här ett tag tror jag nu',
#    'ett viktigt steg att komma ihåg att sätta igång inspelning',
#    'jaha',
#    'annars blir det jobbigt',
#    'ja du har gjort det var bra',
#    'värre bra',
#    'ja men det varför kom det inte fram då',
#    'ja',
#    'magan sextiosju ett livecom',
#    'ja det kan det vara',
#    'vi ska se nu h',
#    'ska jag sätta i laddaren i ',
#    'jaha vad ska vi installera om idag då',
#    'jag kan berätta att igår var jag och wilma och bäste steg gesundaberget',
#    'nja med vilma',
#    'gissa',
#    'ja',
#    'o hon kan ju vara väldigt bestämd så där och röja runt här lite tycker att vi har för stökigt och bordet lite torkat o',
#    'svissfors',
#    'afoken ä inte bara till ikea och köper den',
#    'men vi är bra',
#    'ja',
#    'ja',
#    'faktiskt det kan vi göra',
#    'just nu håller den på att laga',
#    'skuff låset i hennes bil',
#    'som har varit trasigt länge',
#    'ja',
#    'ja det vet inte jag',
#    'de håller på att skruvar isär och grejer och mäter oh',
#    'ja maxe med',
#    'ja',
#    'jo',
#    'så jag ska försöka här i sommar faktiskt att på riktigt läsa en bok',
#    'det var',
#    'det var riktigt längesen faktiskt',
#    'ja',
#    'ja',
#    'det är så att man skulle behöva',
#    'man skulle behöva',
#    'jag bara göra det avsätta en dag liksom',
#    'i ensamhet att bara läsa en bok',
#    'a a',
#    'nu hörde jag att min ena hörlur sa power off',
#    'så nu',
#    'är den ena igång men det räcker väl så här du hör mig bra va',
#    'jag hör dig i ena örat ja e',
#    'ja',
#    'nej vad fan jag kanske inte behöver ha den på laddning jag tarur än så så står den lite stadigare så',
#    'ja',
#    'sen kan jag ju instruera dig om hur man målar ett hus kanske',
#    'jävla massa jobb',
#    'de har ju ni precis gjort så det vet du förstås',
#    'ja',
#    'ja',
#    'ja du som har så många barn hemma också',
#    'ja',
#    'ja',
#    'ja',
#    'et är kanske svårt att vara hemma huvudtaget',
#    'ja',
#    'ja',
#    'det kanske blir så i framtiden att allt fler människors hjärnor kommer att brinna upp i förtid',
#    'ja',
#    'ja',
#    'ja det är man får liksom kartlägga åldringarna förmågor och hur de kan hjälpa varann',
#    'som att',
#    'frost de får faktiskt jobba som städerska på riktigt',
#    'och',
#    'ja',
#    'det kanske liksom skulle bara kunna vara en personal i köket och sedan',
#    'de gamlingar som fortfarande kan laga mat de får laga mat',
#    'ja',
#    'ja',
#    'ja',
#    '',
#    'ja',
#    'jag vore väl nåt för annika',
#    'hon som har jobbat lite i äldrevården hon är',
#    'smart och vill utbilda sig inom hälsa och kanske sjuksköterska',
#    'ja men nu har hon j ju bara jobbat på ett tag',
#    'ja inte det eller',
#    'amen hon läste ju en jöken jar för att få behålla lägenhet',
#    'men det var ju bara en halv termin sen har hon jobbet',
#    'ja',
#    'ja',
#    'ja',
#    'ta hand om oss när vi blir gamla',
#    'jaha det var ju intressant',
#    'ja',
#    'ja',
#    'men beroende på vad man lever i förväg så kan det ju få vara så',
#    'ja',
#    'absolut',
#    'ja ambulansförare tror jag skulle bli eller ambulanssjuksköterska tror jag skulle passa',
#    'ja',
#    'men annars är det kanske så att världen nu är så att',
#    'att hjärnorna brinner upp för fort som sagt alla fall min',
#    'i dag till exempel gick jag ut och målade',
#    'och så här skulle jag målade vita',
#    'och så gick jag upp och så målade jag vindskivan och fönstret längst upp',
#    'och så kände s här ja vad  vad fort det gick rök klar ochså gick jag ner eller undan pendsell o',
#    'och så sa jag det till mats och wilma här ja men nu',
#    'kan vi börja med det ja men',
#    'alltså knutbrädor och hela det där på brända taket där och innertaket då',
#    'ja just',
#    'agar precis mitt för ögon',
#    'ja',
#    'så är det ställt här',
#    'jag borde dö nu',
#    'ja det tycker jag för hon får sluta jobba',
#    'ja för hur ska det bli då det blir höjd pensionsålder så alltfler',
#    'dement kommer ut i arbetslivet titta nu kom vilma också',
#    'ja',
#    'ja det är ju hon som ska ta hand om oss',
#    'isis syster kollektivet',
#    'det är bra a hon har lite undersköterskekompetens i botten',
#    'ja just det rätt material i lägenheten',
#    'är du lite så hungrig wilma',
#    'hon har inte varit med och målat än så länge men hon kommer nog att drabbas',
#    'vi ska måla en gavel röd',
#    'och då är det bra att vara',
#    'så många som möjligt tror jag då kan vi nog vara alla fyra',
#    'fast axel han ligger fortfarande ine och morrar i sin säng',
#    'blir arg när man går in där',
#    'jaha',
#    'ja',
#    'ja',
#    'ja',
#    'ja var håja jag',
#    'och wilma har varit bra hon har fått iväg oss så vi har faktiskt badat',
#    'har vi båda två eller tre kvällar i rad',
#    'a då',
#    'två då  okej da',
#    'v har badig till ho vid holens badplats',
#    'vet inte riktigt där nere vid orsasjön här ganska',
#    'långgrunt fast inte som',
#    'slättbärsdammen de har liksom wilma såg att det är ju mitt lilla paradis',
#    'hon tycker att det är blodiglar och sump i tidningen solo',
#    'hon är lite dum på det',
#    'wilma har alltid rätt ig du ja ja',
#    'det händer väl',
#    'na',
#    'det tycker jag',
#    ' du har väl inte elin wilma',
#    'hur skulle du kunna göra det',
#    'nej det säger jag inte',
#    'systrarna p på krigsstigen',
#    'ja',
#    'ja men jag skulle faktiskt vilja läsa systrarna p',
#    'jag har liksom i allt det här flytt och jag har gjort mig av med så mycket saker och så har jag en låda som står iti uthuset med lite',
#    'porslin som jag ska lämna iväg och där ligger det också en kasse',
#    'da r liksom',
#    'tänkte jag kan inte vara kvar alla systrarna p utan jag har lagt några sista april en kasse men där får jag lite fösont i hjärtat när jag öppnar underklassen',
#    'systrarna p vem kommer att ta hand om den om jag lämnar ner den här på  loppisen',
#    'inget inget barn kommer att köpa systrarna p',
#    'ja jag har faktiskt tänkt på det när laura kommer hit',
#    'då ska jag testa och läsa systrarna pea högt för henne',
#    'och se om hon omedelbart tröttnar',
#    'jag kanske har en till i en viss kasse i uthuset',
#    'ja men skulle liksom molly kunna läsa kullagullas myrtenkrona',
#    'nej',
#    'nej',
#    'sen är hon ju också världsbäst på att ha koll',
#    'liksom på allt vad som händer och inte missa något som sig för jämför man de med laban',
#    'missar allt det och hon hör varendaste',
#    'tonfall och eller om någon skulle vara lite ledsen eller',
#    'eller hur då skulle hon uppfatta det direkt',
#    'nå',
#    'ja verkligen',
#    'och så är ludvig lite mittemellan då',
#    'han har lite både och',
#    'han kan allt',
#    'ja',
#    'men det',
#    'ja men det låter väl väldigt bra om man nu ska bli någon sån här',
#    'chris planerare',
#    'ja',
#    'men han skulle också kunna då jobba på ett demensboende och spela spel med',
#    'hjälpa till att förklara spel för dementa och vifå vinna hela tiden själv',
#    'jaha',
#    'ja',
#    'na',
#    'men hur var det med pappa då',
#    'ja',
#    'ja',
#    'ja det är liksom så annorlunda med honom än  mamma',
#    'liksom han är ju glömsk på ett helt annat vis',
#    'det är mer bara snurrigt',
#    'jaha',
#    'jaha',
#    'jaha vad bra',
#    'ja ja',
#    'ja',
#    'na',
#    'njamen magnus han är väl också så att han håller på',
#    'och talar honom till rätta hela tiden',
#    'det tycker jag han beskriver att han verkligen liksom försöker',
#    'lite så där bestämt tala om hur det faktiskt är',
#    'nej',
#    'ja',
#    'nej',
#    'ja ja just det',
#    'ja ja nu ska jag bara fråga här är det dags att börja måla eller',
#    'vad var det för bild',
#    'det var då när laura la maskar på viktors ben',
#    'han blev så rädd',
#    'laura älskar viktor',
#    'ja jag har fått ett så fint album',
#    'na det är litet vör fint',
#    'javilma och hedvig jossan och',
#    'viktor o de har satt ihop det',
#    'de ä inte elin med nig det kan man undra',
#    'ja men det från kräfthatt kalaset där är hon nog med',
#    'en bild från kräftkalas i vad med alla hattarna',
#    'de är så roligt för herman väldigt kul jag har henne stor berättade solat',
#    'som ligger uppe på krullet',
#    'nej kommer',
#    'jaha men hör du jag undrar om det här ska få räcka för idag',
#    'så ska jag börja måla gaveln innan solen kommer runt huset',
#    'först ska jag måla färdigt di vita då som jag trodde jag var klar med',
#    'sen får vi börja måla rätt',
#    'jag tycker målar1 är roligast för det är bara att kötta på',
#    'liksom',
#    'det är ju liksom  på en fasade ju liksom inte sådär',
#    'så petnoga och så är det ju ganska eu rakt längs brädorna också så det är ju så tydliga kanter så det',
#    'nej det har vi inte gjort',
#    'bellman',
#    'ja men  så målar vi det vita först',
#    'för det är ju liksom vindskivan över som man skvätter nedåt på väggen dåh så målar man över sen',
#    'vi gör så rätt mats eller ordning',
#    'man kan säga att framsidan är klar förutom att vi ska måla grunden',
#    'sen har vi liksom gått runt hörnet och håller på med en gavel där källaren med',
#    'så där håller vi på nu',
#    'och sen är det ju liksom det konstigt nog så är det ju liksom en gavel till eftersom sovrummen är utbyggd i efterhand så det är liksom som en halv gavel till',
#    'och den är väl i lite risigt skick och sen är det ju hela baksidan men där sitter färgen ganska bra det är ju liksom på',
#    'är inte så mycket sol',
#    'där räcker det nog med att tvätta och måla och inte skrapa något',
#    'så det är ju bra',
#    'alla fall',
#    'den är ju tusen också',
#    'mats räkna med att vi ska bli klara med hela huset i sommar',
#    'och det vore väl egentligen skönt och jag tänker maka åtminstone spara ut hus ändå till någon annan gång',
#    'ja',
#    'jaha',
#    'det vore ju en anledning att skaffa instagram igen',
#    'ja ja dent',
#    'när man ser liksom ibland henne i motljus',
#    'så ser det så roligt ut det är som en sky runtom så här',
#    'lite som laura',
#    'ja',
#    'vad gör hon idag och på sin första sommarlovs dag',
#    'a det ska jag tala om för mats',
#    'nä precis',
#    'nej',
#    'ja men vad kul',
#    'vad kul',
#    'vad kul hon skulle ju ha haft någon kompis också som hade en',
#    'ja',
#    'det blir bra att bossa runt med tomas',
#    'na',
#    'ja det ska vi locka med',
#    'det tror jag tror faktiskt att det finns en sån i mora också',
#    'någon sån där',
#    'ja hon som ideellt liksom har byggt upp något sånt där liten',
#    'land',
#    'och så tänkte vi på loura faktiskt när vi åkte till gesunda för där ligger ju tomteland',
#    'och jag har liksom aldrig vart där',
#    'förutom liksom varit på nån sån där show och  äter middag och så men',
#    'men på själva det här tomteland och titta på alla de här älvorna tomtar och det är ju liksom',
#    'lite skådespel ställe så',
#    'ungdomar som jobbar där och spelar tomtar och',
#    'älvor hela sommar',
#    'och hon är väl äntligen någon som är i rätt ålder',
#    'så det skulle vara kul att faktiskt göra om ni kommer hit att vi åker till tomteland med henne',
#    'ja',
#    'ska vi gå upp på berget också titta på utsikten',
#    'ja',
#    'ja',
#    'ja',
#    'ja ja men det är bra',
#    'sen kanske jag kontakta dig när jag ska skicka iväg de här men',
#    'och lägger dem i den där dropboxen',
#    'ja',
#    'ja',
#    'ja',
#    'ja men det är ju bra bara höra av skicka ett meddelande så där när det passar så kan man',
#    'ta någon stund så här',
#    'ja det blir bra',
#    'perfekt',
#    'men hälsa alla',
#    'ja',
#    'hejdå']})

# %%
#filtered = filter(lambda x : "deep-phon" in x[0][2] and x[0][-1] >= 0.6 and x[0][-1] < 0.7, res)
filtered = list(filter(None, res))
x = min(filtered, key= lambda x: x[1]["ensemble-wer"].mean)[1]["ensemble-wer"]
arg = np.argmin([x[1]["ensemble-wer"].mean for x in filtered])
print(f"{x.mean} ± {x.std}", arg)
filtered[arg]
# Out:
# 0.1520973422990714 ± 0 205
# ((<function google_kb_z_speaker.experiments.ensemble(phonemizer, ratio_threshold, bunches=None, device=None, use_phonemizer=None)>,
#   1,
#   <function phonemes.phonemizer_wrapper.<locals>.phonemizer_to_return(texts: Union[str, List[str]], lang)>,
#   0.6154135338345864),
#  {'google_wer': <experiment_helpers.ExperimentResult at 0x7f048d61a160>,
#   'kb_wer': <experiment_helpers.ExperimentResult at 0x7f048d61a100>,
#   'ensemble-wer': <experiment_helpers.ExperimentResult at 0x7f048d61a130>})

# %% [markdown]
# ### Error analysis
#
# Research questions
# - On which examples was WER improved with the ensemble
# - On which examples is the ensemble WER worse than before?
# - On which examples is grapheme ensemble WER better than phoneme ensemble WER
# - On which examples is grapheme ensemble WER worse than phoneme ensemble WER

# %%
def err_anal(bunches):
    phonemizer = phonemizer_wrapper(init_phonemizer("cuda", "models/deep-phonemizer-se.pt", stress_marks=True), None, include_stress_marks=True)
    res_graph = ensemble(phonemizer, 0.6, bunches=bunches, device="cuda", use_phonemizer=False)
    res_phoneme = ensemble(phonemizer, 0.6, bunches=bunches, device="cuda", use_phonemizer=True)
    # Copy bunches
    bunches = {k:v for k,v in bunches.items()}
    bunches["grapheme"] = res_graph["ensemble_outputs"]
    bunches["phoneme"] = res_phoneme["ensemble_outputs"]
    bunch_list = [{k: bunches[k][i] for k in bunches} for i in range(len([x for x in bunches.values()][0]))]
    # Subsets for rqs
    rq1 = []
    rq2 = []
    rq3 = []
    rq4 = []
    rq5 = []
    rq6 = []
    for bunch in bunch_list:
        len_correct = len(bunch["correct"])
        kb_wer = wer(bunch["correct"], bunch["kb"])
        graph_wer = wer(bunch["correct"], bunch["grapheme"])
        phoneme_wer = wer(bunch["correct"], bunch["phoneme"])
        if phoneme_wer < kb_wer:
            rq1.append(bunch)
        if phoneme_wer > kb_wer:
            rq2.append(bunch)
        if graph_wer < phoneme_wer:
            rq3.append(bunch)
        if graph_wer > phoneme_wer:
            rq4.append(bunch)
        if graph_wer < kb_wer:
            rq5.append(bunch)
        if graph_wer > kb_wer:
            rq6.append(bunch)
    
    return [rq1,rq2,rq3,rq4,rq5,rq6]

# %%
        
for i,x in enumerate(err_anal(bunches)):
    print("===================")
    print(f"Len Rq{i+1} :", len(x), "percentage: ", len(x)/ 911)
    samples = random.sample(x,k=5)
    for xi in samples:
        print(":::::::::::::::::::::::")
        print("Correct ", xi["correct"])
        print("Google ", xi["google"])
        print("KB ", xi["kb"])
        print("PhonemeEns ",  xi["phoneme"])
        print("Grapheme ",  xi["grapheme"])
# Out:
#   0%|          | 0/911 [00:00<?, ?it/s]
#   0%|          | 0/911 [00:00<?, ?it/s]
# ===================
# Len Rq1 : 161 percentage:  0.17672886937431395
# :::::::::::::::::::::::
# Correct  och hur mår du och så där
# Google  och hur mår du och så där
# KB  och hur mår du och sådär
# PhonemeEns  och hur mår du och så där
# Grapheme  och hur mår du och så där
# :::::::::::::::::::::::
# Correct  att jag kanske har fyrtio stycken på min lista som jag är
# Google  att jag kanske har 40 stycken på min lista som jag är
# KB  att jag kanske har fyrtio stycken på min lista som jag r
# PhonemeEns  att jag kanske har fyrtio stycken på min lista som jag är
# Grapheme  att jag kanske har fyrtio stycken på min lista som jag är
# :::::::::::::::::::::::
# Correct  ja
# Google  ja
# KB  a
# PhonemeEns  ja
# Grapheme  ja
# :::::::::::::::::::::::
# Correct  ja jag tänkte häromdagen på också när ni ska komma hit och hälsa på egentligen och var ni ska sova allihopa
# Google  ja jag tänkte häromdagen på också när ni ska komma hit och hälsa på egentligen att han ska sova
# KB  ja jag tänkte häromdan på också när ni ska komma hit och hälsa på egentligen och vad ni ska sova allihop
# PhonemeEns  ja jag tänkte häromdagen på också när ni ska komma hit och hälsa på egentligen och vad ni ska sova allihop
# Grapheme  ja jag tänkte häromdagen på också när ni ska komma hit och hälsa på egentligen och vad ni ska sova allihop
# :::::::::::::::::::::::
# Correct  men
# Google  men
# KB  män
# PhonemeEns  men
# Grapheme  men
# ===================
# Len Rq2 : 82 percentage:  0.09001097694840834
# :::::::::::::::::::::::
# Correct  och så köpte jag lite sättpotatis också av några olika sorter
# Google  och så köpte jag lite sättpotatis också har några olika sorter
# KB  och så köpte jag lite sättpotatis också av några olika sorter
# PhonemeEns  och så köpte jag lite sättpotatis också har några olika sorter
# Grapheme  och så köpte jag lite sättpotatis också av några olika sorter
# :::::::::::::::::::::::
# Correct  ja men jag tänker också om man skulle ja dels kanske man skulle behöva på pappa ja
# Google  ja men jag tänker också att man skulle ha det kanske man skulle behöva på pappa ja
# KB  ja men och jag tänker också om man skulle ja dels kanske man skulle behöva hälsa på pappa jag
# PhonemeEns  ja men och jag tänker också om man skulle ha det kanske man skulle behöva hälsa på pappa ja
# Grapheme  ja men och jag tänker också om man skulle ha det kanske man skulle behöva hälsa på pappa ja
# :::::::::::::::::::::::
# Correct  jag kanske har en till i en viss kasse i uthuset
# Google  jag kanske har en till i en whiskas i uthuset
# KB  jag kanske har en till i en viss kasse i uthuset
# PhonemeEns  jag kanske har en till i en whiskas i uthuset
# Grapheme  jag kanske har en till i en viss kasse i uthuset
# :::::::::::::::::::::::
# Correct  jag blir lite full i skratt för vi vi var så himla på krigsstigen först då liksom
# Google  finns det för ditt skratt för vi var så himla på krigsstigen första liksom
# KB  blir inte full i skratt för vi var så himla på krigsstigen först och liksom
# PhonemeEns  blir inte full i skratt för vi var så himla på krigsstigen första liksom
# Grapheme  blir inte full i skratt för vi var så himla på krigsstigen första liksom
# :::::::::::::::::::::::
# Correct  jag har faktiskt gott om småkakor för en gångs skull
# Google  jag har faktiskt gott om småkakor för en gång skull
# KB  jag har faktiskt gott om småkakor för en gångs skull
# PhonemeEns  jag har faktiskt gott om småkakor för en gång skull
# Grapheme  jag har faktiskt gott om småkakor för en gång skull
# ===================
# Len Rq3 : 66 percentage:  0.07244785949506037
# :::::::::::::::::::::::
# Correct  ja
# Google  ja
# KB  a
# PhonemeEns  a
# Grapheme  ja
# :::::::::::::::::::::::
# Correct  ja
# Google  ja
# KB  a
# PhonemeEns  a
# Grapheme  ja
# :::::::::::::::::::::::
# Correct  eller kanske om jag får säger hej hur står det till
# Google  om jag får säger hej hur står det till
# KB  eller kanske oom jag förser hej hur står det till
# PhonemeEns  eller kanske oom jag förser hej hur står det till
# Grapheme  eller kanske oom jag får säger hej hur står det till
# :::::::::::::::::::::::
# Correct  oj
# Google  oj
# KB  o
# PhonemeEns  o
# Grapheme  oj
# :::::::::::::::::::::::
# Correct  helgen var det väl för då då hade vi vänstermöte här hemma hos mig i trädgården
# Google  helgen var det väl för då hade vi vänster möte hemma hos mig i trädgården
# KB  helgen var det väl för dådå hade vi vänstermöte härhemma hos mig i trädgården
# PhonemeEns  helgen var det väl för dådå hade vi vänster möte hemma hos mig i trädgården
# Grapheme  helgen var det väl för då hade vi vänster möte hemma hos mig i trädgården
# ===================
# Len Rq4 : 10 percentage:  0.010976948408342482
# :::::::::::::::::::::::
# Correct  a men så gjorde jag också
# Google  ja men så gjorde jag också
# KB  a men så gjorde jag också
# PhonemeEns  a men så gjorde jag också
# Grapheme  ja men så gjorde jag också
# :::::::::::::::::::::::
# Correct  så petnoga och så är det ju ganska det är ju rakt längs brädorna och så så det är ju så tydliga kanter så det
# Google  så petnoga och så är det ganska de ju rakt längs brädorna också så det är ju så tydliga kanter så det
# KB  så petnoga och så är det ju ganska eu rakt längs brädorna och så så det är ju så tydliga kanter så de
# PhonemeEns  så petnoga och så är det ju ganska eu rakt längs brädorna och så så det är ju så tydliga kanter så de
# Grapheme  så petnoga och så är det ju ganska eu rakt längs brädorna också så det är ju så tydliga kanter så det
# :::::::::::::::::::::::
# Correct  vi gör så rätt mats håller ordning
# Google  nya stället mats eller ordning
# KB  vi gör så rätt mats håller ordning
# PhonemeEns  vi gör så rätt mats håller ordning
# Grapheme  vi gör så rätt mats eller ordning
# :::::::::::::::::::::::
# Correct  penslade med ägg och strödda med hackade nötter
# Google  penslade med ägg och strö med hackade nötter
# KB  penslade med ägg och strödda med hackade nötter
# PhonemeEns  penslade med ägg och strödda med hackade nötter
# Grapheme  penslade med ägg och strö med hackade nötter
# :::::::::::::::::::::::
# Correct  men tänk det är min också
# Google  men tänkte min också
# KB  men tänk det min också
# PhonemeEns  men tänk det min också
# Grapheme  men tänkte min också

# %% [markdown]
# ## Phonemizer dict evaluation
#
# Running the different phonemizers and testing their outputs with the provied stres__lex dictionary

# %%
def phonemizer_eval(model_path, device=None, stub=None):
    print("Stub is ", stub)
    phonemizer = init_phonemizer(device, model_path)
    phoneme_dict = read_phoneme_dict("./models/stress_lex_mtm.txt")
    print("Preprocessing dict")
    keys_order = list(phoneme_dict.keys())
    # Downsample
    values_order = [phoneme_dict[k] for k in keys_order]
    print("Running phonemizer")
    count_correct = 0
    outputs = []
    pbar = tqdm(list(enumerate(keys_order)))
    for i,k in pbar:
        true_phonemes = "".join(phoneme_dict[k])
        if not stub:
            phon_output = phonemizer(k,"se")
        else:
            phon_output = "a-form"
        outputs.append(phon_output)
        if phon_output==true_phonemes:
            count_correct += 1

        if i % 2000 == 0:
            pbar.set_postfix_str(f"Accuracy: {count_correct / len(keys_order):.3f}")
    output_dict = {k:v for k,v in zip(keys_order, outputs)}

    return {
        "accuracy" : count_correct / len(keys_order),
        "output_dict" : output_dict
    }

# %%
model_paths = [
            'models/deep-phonemizer-se.pt',
            'models/DeepPhon/winhome/Downloads/DeepPhon_to_send/best_model.pt',
            'models/DeepPhon/winhome/Downloads/DeepPhon_to_send/model_step_40k.pt',
            
]
kwargs= {
    "device" : "cuda",
    "stub" : True
}
res = grid(phonemizer_eval, [model_paths], kwargs, stub=False)
res
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Stub is  True
# Preprocessing dict
# Running phonemizer
#   0%|          | 0/349839 [00:00<?, ?it/s]
# Stub is  True
# Preprocessing dict
# Running phonemizer
#   0%|          | 0/349839 [00:00<?, ?it/s]
# Stub is  True
# Preprocessing dict
# Running phonemizer
#   0%|          | 0/349839 [00:00<?, ?it/s]
# [(('models/deep-phonemizer-se.pt',),
#   {'accuracy': 0.0,
#    'output_dict': {'a': 'a-form',
#     'a-aktier': 'a-form',
#     'a-banan': 'a-form',
#     'a-ekonomi': 'a-form',
#     'a-et': 'a-form',
#     'a-final': 'a-form',
#     'a-finalen': 'a-form',
#     'a-flyg': 'a-form',
#     'a-form': 'a-form',
#     'a-gruppen': 'a-form',
#     'a-juniorer': 'a-form',
#     'a-juniorerna': 'a-form',
#     'a-juniorlaget': 'a-form',
#     'a-kamper': 'a-form',
#     'a-kassa': 'a-form',
#     'a-kassan': 'a-form',
#     'a-kassor': 'a-form',
#     'a-kassorna': 'a-form',
#     'a-lag': 'a-form',
#     'a-lagare': 'a-form',
#     'a-lagarna': 'a-form',
#     'a-laget': 'a-form',
#     'a-lagets': 'a-form',
#     'a-lagsjuniorerna': 'a-form',
#     'a-lagspelare': 'a-form',
#     'a-lagsspelare': 'a-form',
#     'a-landskamper': 'a-form',
#     'a-landslag': 'a-form',
#     'a-landslaget': 'a-form',
#     'a-listan': 'a-form',
#     'a-ljud': 'a-form',
#     'a-ljudet': 'a-form',
#     'a-n': 'a-form',
#     'a-nummer': 'a-form',
#     'a-pojke': 'a-form',
#     'a-pressen': 'a-form',
#     'a-pressens': 'a-form',
#     'a-presskoncernens': 'a-form',
#     'a-presstidningar': 'a-form',
#     'a-presstidningarna': 'a-form',
#     'a-provet': 'a-form',
#     'a-trupp': 'a-form',
#     'a-truppen': 'a-form',
#     'a-tur': 'a-form',
#     'a-vitamin': 'a-form',
#     'a-vitaminliknande': 'a-form',
#     'a:son': 'a-form',
#     'a_a': 'a-form',
#     'a_b_c_gatan': 'a-form',
#     'a_bergmans_väg': 'a-form',
#     'a_c_lindblads_gata': 'a-form',
#     'a_e_holmbergs_gata': 'a-form',
#     'a_f_håkanssons_väg': 'a-form',
#     'a_odhners_gata': 'a-form',
#     'a_p_sjöbergs_väg': 'a-form',
#     'aabel': 'a-form',
#     'aaben': 'a-form',
#     'aaby': 'a-form',
#     'aadde': 'a-form',
#     'aadel': 'a-form',
#     'aadland': 'a-form',
#     'aadli': 'a-form',
#     'aadu': 'a-form',
#     'aadén': 'a-form',
#     'aagaard': 'a-form',
#     'aage': 'a-form',
#     'aagesen': 'a-form',
#     'aagesson': 'a-form',
#     'aagot': 'a-form',
#     'aagots': 'a-form',
#     'aahlborg': 'a-form',
#     'aaker': 'a-form',
#     'aakerholm': 'a-form',
#     'aakre': 'a-form',
#     'aalbers': 'a-form',
#     'aalborg': 'a-form',
#     'aalerud': 'a-form',
#     'aall': 'a-form',
#     'aalstad': 'a-form',
#     'aalsö': 'a-form',
#     'aalto': 'a-form',
#     'aalto-vasen': 'a-form',
#     'aaltonen': 'a-form',
#     'aalvik': 'a-form',
#     'aaman': 'a-form',
#     'aamisepp': 'a-form',
#     'aamlid': 'a-form',
#     'aamodt': 'a-form',
#     'aandahl': 'a-form',
#     'aandstad': 'a-form',
#     'aanerud': 'a-form',
#     'aanesen': 'a-form',
#     'aanstad': 'a-form',
#     'aapo': 'a-form',
#     'aardal': 'a-form',
#     'aare': 'a-form',
#     'aarea': 'a-form',
#     'aarenstrup': 'a-form',
#     'aarflot': 'a-form',
#     'aarholdt': 'a-form',
#     'aarhus': 'a-form',
#     'aarna': 'a-form',
#     'aarne': 'a-form',
#     'aarni': 'a-form',
#     'aarnio': 'a-form',
#     'aarno': 'a-form',
#     'aarnseth': 'a-form',
#     'aaro': 'a-form',
#     'aaron': 'a-form',
#     'aarons': 'a-form',
#     'aarre': 'a-form',
#     'aarseth': 'a-form',
#     'aarskog': 'a-form',
#     'aarsrud': 'a-form',
#     'aarstad': 'a-form',
#     'aarto': 'a-form',
#     'aartola': 'a-form',
#     'aarvidsson': 'a-form',
#     'aarås': 'a-form',
#     'aaröe': 'a-form',
#     'aas': 'a-form',
#     'aasa': 'a-form',
#     'aasberg': 'a-form',
#     'aase': 'a-form',
#     'aasen': 'a-form',
#     'aasgaard': 'a-form',
#     'aasgård': 'a-form',
#     'aasheim': 'a-form',
#     'aasland': 'a-form',
#     'aaslund': 'a-form',
#     'aasma': 'a-form',
#     'aasmundsen': 'a-form',
#     'aastradsen': 'a-form',
#     'aastrup': 'a-form',
#     'aate': 'a-form',
#     'aatos': 'a-form',
#     'aatto': 'a-form',
#     'aava': 'a-form',
#     'aavik': 'a-form',
#     'ab': 'a-form',
#     'abadi': 'a-form',
#     'abarca': 'a-form',
#     'abassi': 'a-form',
#     'abba': 'a-form',
#     'abbas': 'a-form',
#     'abbasi': 'a-form',
#     'abbassi': 'a-form',
#     'abbe': 'a-form',
#     'abbedissa': 'a-form',
#     'abbedissan': 'a-form',
#     'abbedissans': 'a-form',
#     'abbedissavägen': 'a-form',
#     'abbedissgatan': 'a-form',
#     'abbefalk': 'a-form',
#     'abbefors': 'a-form',
#     'abbegren': 'a-form',
#     'abbegård': 'a-form',
#     'abbekås': 'a-form',
#     'abbekåsgatan': 'a-form',
#     'abbeling': 'a-form',
#     'abbemalm': 'a-form',
#     'abbemark': 'a-form',
#     'abben': 'a-form',
#     'abberud': 'a-form',
#     'abberyd': 'a-form',
#     'abbesjö': 'a-form',
#     'abbestam': 'a-form',
#     'abbesten': 'a-form',
#     'abbetoft': 'a-form',
#     'abbevik': 'a-form',
#     'abbhagen': 'a-form',
#     'abbhammar': 'a-form',
#     'abbhed': 'a-form',
#     'abbing': 'a-form',
#     'abbor': 'a-form',
#     'abborrar': 'a-form',
#     'abborrarna': 'a-form',
#     'abborrart': 'a-form',
#     'abborrartad': 'a-form',
#     'abborre': 'a-form',
#     'abborrebergsvägen': 'a-form',
#     'abborregatan': 'a-form',
#     'abborren': 'a-form',
#     'abborrestigen': 'a-form',
#     'abborrevägen': 'a-form',
#     'abborrfisk': 'a-form',
#     'abborrfiske': 'a-form',
#     'abborrgatan': 'a-form',
#     'abborrgrund': 'a-form',
#     'abborrgränd': 'a-form',
#     'abborrkroken': 'a-form',
#     'abborrmunnen': 'a-form',
#     'abborrpinne': 'a-form',
#     'abborrstigen': 'a-form',
#     'abborrtjärnsvägen': 'a-form',
#     'abborrtorpsvägen': 'a-form',
#     'abborrträsk': 'a-form',
#     'abborrvägen': 'a-form',
#     'abbot': 'a-form',
#     'abboten': 'a-form',
#     'abbotens': 'a-form',
#     'abbotens_väg': 'a-form',
#     'abbotsdöme': 'a-form',
#     'abbotsgatan': 'a-form',
#     'abbotskap': 'a-form',
#     'abbotvägen': 'a-form',
#     'abboud': 'a-form',
#     'abbreviation': 'a-form',
#     'abbreviatur': 'a-form',
#     'abbreviera': 'a-form',
#     'abbreviering': 'a-form',
#     'abbås': 'a-form',
#     'abbé': 'a-form',
#     'abc': 'a-form',
#     'abc-bok': 'a-form',
#     'abc-boken': 'a-form',
#     'abc-nytt': 'a-form',
#     'abd': 'a-form',
#     'abda': 'a-form',
#     'abdalla': 'a-form',
#     'abdallah': 'a-form',
#     'abdel': 'a-form',
#     'abdelahad': 'a-form',
#     'abdelaziz': 'a-form',
#     'abdelkader': 'a-form',
#     'abdellah': 'a-form',
#     'abdellatif': 'a-form',
#     'abderit': 'a-form',
#     'abderitisk': 'a-form',
#     'abderrahmane': 'a-form',
#     'abdeslam': 'a-form',
#     'abdi': 'a-form',
#     'abdikarim': 'a-form',
#     'abdikation': 'a-form',
#     'abdikationsakt': 'a-form',
#     'abdikera': 'a-form',
#     'abdikerade': 'a-form',
#     'abdikerar': 'a-form',
#     'abdikerat': 'a-form',
#     'abdikering': 'a-form',
#     'abdillahi': 'a-form',
#     'abdirahman': 'a-form',
#     'abdirizak': 'a-form',
#     'abdo': 'a-form',
#     'abdol': 'a-form',
#     'abdolhossein': 'a-form',
#     'abdollah': 'a-form',
#     'abdollahi': 'a-form',
#     'abdolreza': 'a-form',
#     'abdomen': 'a-form',
#     'abdominala': 'a-form',
#     'abdon': 'a-form',
#     'abdu': 'a-form',
#     'abduktiv': 'a-form',
#     'abdul': 'a-form',
#     'abdulah': 'a-form',
#     'abdulahad': 'a-form',
#     'abdulaziz': 'a-form',
#     'abdulhadi': 'a-form',
#     'abdulhamid': 'a-form',
#     'abdulkader': 'a-form',
#     'abdulkadir': 'a-form',
#     'abdulkarim': 'a-form',
#     'abdulkerim': 'a-form',
#     'abdulla': 'a-form',
#     'abdullah': 'a-form',
#     'abdullahad': 'a-form',
#     'abdullahi': 'a-form',
#     'abdulle': 'a-form',
#     'abdulmasih': 'a-form',
#     'abdulmesih': 'a-form',
#     'abdulrahman': 'a-form',
#     'abdulsalam': 'a-form',
#     'abdurahman': 'a-form',
#     'abeba': 'a-form',
#     'abebe': 'a-form',
#     'abed': 'a-form',
#     'abedal': 'a-form',
#     'abedi': 'a-form',
#     'abedian': 'a-form',
#     'abedin': 'a-form',
#     'abefelt': 'a-form',
#     'abefors': 'a-form',
#     'abel': 'a-form',
#     'abel_beckers_gata': 'a-form',
#     'abeleen': 'a-form',
#     'abelin': 'a-form',
#     'abeling': 'a-form',
#     'abelius': 'a-form',
#     'abelli': 'a-form',
#     'abeln': 'a-form',
#     'abelson': 'a-form',
#     'abelsson': 'a-form',
#     'abelt': 'a-form',
#     'abeman': 'a-form',
#     'aben': 'a-form',
#     'abenius': 'a-form',
#     'aber': 'a-form',
#     'abergavägen': 'a-form',
#     'aberger': 'a-form',
#     'aberin': 'a-form',
#     'aberius': 'a-form',
#     'aberration': 'a-form',
#     'abersten': 'a-form',
#     'aberén': 'a-form',
#     'abessinsk': 'a-form',
#     'abessinska': 'a-form',
#     'abi': 'a-form',
#     'abid': 'a-form',
#     'abidi': 'a-form',
#     'abilitet': 'a-form',
#     'abin': 'a-form',
#     'abir': 'a-form',
#     'abisko': 'a-form',
#     'abiskoområdet': 'a-form',
#     'abiskovägen': 'a-form',
#     'abjörnssons_väg': 'a-form',
#     'abjörnssonsvägen': 'a-form',
#     'ablahad': 'a-form',
#     'ablation': 'a-form',
#     'ablativ': 'a-form',
#     'ablativform': 'a-form',
#     'abler': 'a-form',
#     'abmorvägen': 'a-form',
#     'abnell': 'a-form',
#     'abner': 'a-form',
#     'abnorm': 'a-form',
#     'abnorma': 'a-form',
#     'abnormitet': 'a-form',
#     'abnormitetens': 'a-form',
#     'abnormiteter': 'a-form',
#     'abnormt': 'a-form',
#     'abnormtillstånd': 'a-form',
#     'abolfazl': 'a-form',
#     'abolghasem': 'a-form',
#     'abolins': 'a-form',
#     'abolition': 'a-form',
#     'abonius': 'a-form',
#     'abonnemang': 'a-form',
#     'abonnemangen': 'a-form',
#     'abonnemanget': 'a-form',
#     'abonnemangsavgiften': 'a-form',
#     'abonnemangsavtal': 'a-form',
#     'abonnemangsbyte': 'a-form',
#     'abonnemangserbjudande': 'a-form',
#     'abonnemangsfritt': 'a-form',
#     'abonnemangsfråga': 'a-form',
#     'abonnemangsfrågor': 'a-form',
#     'abonnemangskonserterna': 'a-form',
#     'abonnemangsnummer': 'a-form',
#     'abonnemangspris': 'a-form',
#     'abonnent': 'a-form',
#     'abonnenten': 'a-form',
#     'abonnenter': 'a-form',
#     'abonnenterna': 'a-form',
#     'abonnentskaran': 'a-form',
#     'abonnera': 'a-form',
#     'abonnerad': 'a-form',
#     'abonnerade': 'a-form',
#     'abonnerar': 'a-form',
#     'abonnerat': 'a-form',
#     'aboriginer': 'a-form',
#     'aboriginerna': 'a-form',
#     'aborrvägen': 'a-form',
#     'abort': 'a-form',
#     'aborten': 'a-form',
#     'aborter': 'a-form',
#     'abortera': 'a-form',
#     'aborterade': 'a-form',
#     'aborterna': 'a-form',
#     'abortframkallande': 'a-form',
#     'abortframkallare': 'a-form',
#     'abortfråga': 'a-form',
#     'abortfrågan': 'a-form',
#     'abortförbud': 'a-form',
#     'abortförebyggande': 'a-form',
#     'abortingreppet': 'a-form',
#     'abortiv': 'a-form',
#     'abortklinik': 'a-form',
#     'abortkliniker': 'a-form',
#     'abortlag': 'a-form',
#     'abortlagen': 'a-form',
#     'abortlagstiftning': 'a-form',
#     'abortlagstiftningen': 'a-form',
#     'abortmotståndare': 'a-form',
#     'abortmotståndarna': 'a-form',
#     'abortpiller': 'a-form',
#     'abortpillret': 'a-form',
#     'abortresa': 'a-form',
#     'aborträtten': 'a-form',
#     'abortrådgivning': 'a-form',
#     'abortsökande': 'a-form',
#     'abortör': 'a-form',
#     'abou': 'a-form',
#     'aboud': 'a-form',
#     'abradera': 'a-form',
#     'abradering': 'a-form',
#     'abraha': 'a-form',
#     'abraham': 'a-form',
#     'abraham_ahléns_väg': 'a-form',
#     'abraham_bäckgatan': 'a-form',
#     'abrahams': 'a-form',
#     'abrahamsberg': 'a-form',
#     'abrahamsbergsvägen': 'a-form',
#     'abrahamsbovägen': 'a-form',
#     'abrahamsen': 'a-form',
#     'abrahamson': 'a-form',
#     'abrahamsson': 'a-form',
#     'abrahamsvägen': 'a-form',
#     'abrahim': 'a-form',
#     'abrahmson': 'a-form',
#     'abrahmsson': 'a-form',
#     'abrahmsén': 'a-form',
#     'abrakadabra': 'a-form',
#     'abram': 'a-form',
#     'abramsgård': 'a-form',
#     'abramson': 'a-form',
#     'abramsson': 'a-form',
#     'abramsvägen': 'a-form',
#     'abrasion': 'a-form',
#     'abrasionsbrant': 'a-form',
#     'abrehet': 'a-form',
#     'abrell': 'a-form',
#     'abresparr': 'a-form',
#     'abreu': 'a-form',
#     'abring': 'a-form',
#     'abrupt': 'a-form',
#     'abrupta': 'a-form',
#     'absalons_väg': 'a-form',
#     'absens': 'a-form',
#     'abshir': 'a-form',
#     'absid': 'a-form',
#     'absidgatan': 'a-form',
#     'absidkyrka': 'a-form',
#     'absint': 'a-form',
#     'absintflaska': 'a-form',
#     'abskissa': 'a-form',
#     'absolut': 'a-form',
#     'absoluta': 'a-form',
#     'absolute': 'a-form',
#     'absolutflaskan': 'a-form',
#     'absolution': 'a-form',
#     'absolutism': 'a-form',
#     'absolutist': 'a-form',
#     'absolutisterna': 'a-form',
#     'absolutistisk': 'a-form',
#     'absolvera': 'a-form',
#     'absolvering': 'a-form',
#     'absorbera': 'a-form',
#     'absorberad': 'a-form',
#     'absorberade': 'a-form',
#     'absorberar': 'a-form',
#     'absorberas': 'a-form',
#     'absorberat': 'a-form',
#     'absorberats': 'a-form',
#     'absorption': 'a-form',
#     'absorptionen': 'a-form',
#     'absorptionsband': 'a-form',
#     'absorptionsförmåga': 'a-form',
#     'abstinens': 'a-form',
#     'abstinensbesvär': 'a-form',
#     'abstinenseffekter': 'a-form',
#     'abstract': 'a-form',
#     'abstrahera': 'a-form',
#     'abstraherande': 'a-form',
#     'abstrahering': 'a-form',
#     'abstrakt': 'a-form',
#     'abstrakta': 'a-form',
#     'abstraktion': 'a-form',
#     'abstraktionen': 'a-form',
#     'abstraktionens': 'a-form',
#     'abstraktioner': 'a-form',
#     'abstraktionsförmåga': 'a-form',
#     'abstraktionsnivå': 'a-form',
#     'abstraktionssynen': 'a-form',
#     'abstrus': 'a-form',
#     'absurd': 'a-form',
#     'absurda': 'a-form',
#     'absurdhet': 'a-form',
#     'absurdism': 'a-form',
#     'absurdismen': 'a-form',
#     'absurdist': 'a-form',
#     'absurdisterna': 'a-form',
#     'absurdistisk': 'a-form',
#     'absurdistiska': 'a-form',
#     'absurditet': 'a-form',
#     'absurditetens': 'a-form',
#     'absurditeter': 'a-form',
#     'absurdum': 'a-form',
#     'absurt': 'a-form',
#     'abtin': 'a-form',
#     'abu': 'a-form',
#     'abul': 'a-form',
#     'abundans': 'a-form',
#     'abundant': 'a-form',
#     'abus': 'a-form',
#     'abwin': 'a-form',
#     'abygatan': 'a-form',
#     'abyssal': 'a-form',
#     'abäcksvägen': 'a-form',
#     'acar': 'a-form',
#     'accedera': 'a-form',
#     'acceleration': 'a-form',
#     'accelerationen': 'a-form',
#     'accelerationssträcka': 'a-form',
#     'accelerator': 'a-form',
#     'acceleratorer': 'a-form',
#     'acceleratorerna': 'a-form',
#     'acceleratorernas': 'a-form',
#     'acceleratorn': 'a-form',
#     'accelerera': 'a-form',
#     'accelererade': 'a-form',
#     'accelererades': 'a-form',
#     'accelererande': 'a-form',
#     'accelererar': 'a-form',
#     'accelereras': 'a-form',
#     'accelererat': 'a-form',
#     'accelerering': 'a-form',
#     'accent': 'a-form',
#     'accenten': 'a-form',
#     'accenter': 'a-form',
#     'accentuera': 'a-form',
#     'accentuerad': 'a-form',
#     'accentuerade': 'a-form',
#     'accentuerades': 'a-form',
#     'accentuerar': 'a-form',
#     'accentueras': 'a-form',
#     'accentuerat': 'a-form',
#     'accentuerats': 'a-form',
#     'accentuering': 'a-form',
#     'accept': 'a-form',
#     'acceptabel': 'a-form',
#     'acceptabelt': 'a-form',
#     'acceptabla': 'a-form',
#     'acceptans': 'a-form',
#     'acceptansen': 'a-form',
#     'accepten': 'a-form',
#     'acceptera': 'a-form',
#     'accepterad': 'a-form',
#     'accepterade': 'a-form',
#     'accepterades': 'a-form',
#     'accepterande': 'a-form',
#     'accepterandet': 'a-form',
#     'accepterar': 'a-form',
#     'accepteras': 'a-form',
#     'accepterat': 'a-form',
#     'accepterats': 'a-form',
#     'access': 'a-form',
#     'accessoar': 'a-form',
#     'accessoarer': 'a-form',
#     'accesstjänster': 'a-form',
#     'accis': 'a-form',
#     'accisfri': 'a-form',
#     'accismedel': 'a-form',
#     'accispliktig': 'a-form',
#     'acetat': 'a-form',
#     'acetatsilke': 'a-form',
#     'aceton': 'a-form',
#     'acetylen': 'a-form',
#     'acetylengas': 'a-form',
#     'acetylenlampa': 'a-form',
#     'acetylsalicylsyra': 'a-form',
#     'acevedo': 'a-form',
#     'achilleas': 'a-form',
#     'achim': 'a-form',
#     'achmed': 'a-form',
#     'achour': 'a-form',
#     'achrén': 'a-form',
#     'achteenberg': 'a-form',
#     'achtenberg': 'a-form',
#     'achtman': 'a-form',
#     'aciditet': 'a-form',
#     'ack': 'a-form',
#     'ackalin': 'a-form',
#     'ackberger': 'a-form',
#     'acke': 'a-form',
#     'ackeberg': 'a-form',
#     'ackebjer': 'a-form',
#     'ackebo': 'a-form',
#     'ackeborn': 'a-form',
#     'ackebrink': 'a-form',
#     'ackeby': 'a-form',
#     'ackedahl': 'a-form',
#     'ackefelt': 'a-form',
#     'ackefjord': 'a-form',
#     'ackefors': 'a-form',
#     'ackegård': 'a-form',
#     'ackehed': 'a-form',
#     'ackelid': 'a-form',
#     'ackelin': 'a-form',
#     'ackelind': 'a-form',
#     'ackell': 'a-form',
#     'ackelman': 'a-form',
#     'ackelöv': 'a-form',
#     'ackemalm': 'a-form',
#     'ackemar': 'a-form',
#     'ackemark': 'a-form',
#     'ackemo': 'a-form',
#     'ackenäs': 'a-form',
#     'ackerberg': 'a-form',
#     'ackerblad': 'a-form',
#     'ackerborg': 'a-form',
#     'ackerby': 'a-form',
#     'ackerdahl': 'a-form',
#     'ackerdal': 'a-form',
#     'ackered': 'a-form',
#     'ackerfeldt': 'a-form',
#     'ackerfors': 'a-form',
#     'ackerhans': 'a-form',
#     'ackerholm': 'a-form',
#     'ackerholt': 'a-form',
#     'ackerhus': 'a-form',
#     'ackerman': 'a-form',
#     'ackermann': 'a-form',
#     'ackermark': 'a-form',
#     'ackerot': 'a-form',
#     'ackers': 'a-form',
#     'ackerstedt': 'a-form',
#     'ackerstierna': 'a-form',
#     'ackerstig': 'a-form',
#     'ackerstrand': 'a-form',
#     'ackerud': 'a-form',
#     'ackerup': 'a-form',
#     'ackeryd': 'a-form',
#     'ackesjö': 'a-form',
#     'ackeskog': 'a-form',
#     'ackesten': 'a-form',
#     'ackestig': 'a-form',
#     'ackeström': 'a-form',
#     'ackeståhl': 'a-form',
#     'ackestål': 'a-form',
#     'acketoft': 'a-form',
#     'ackevall': 'a-form',
#     'ackevik': 'a-form',
#     'ackewald': 'a-form',
#     'ackfeldt': 'a-form',
#     'ackfjäll': 'a-form',
#     'ackfjärd': 'a-form',
#     'ackhammar': 'a-form',
#     'ackheden': 'a-form',
#     'acki': 'a-form',
#     'acking': 'a-form',
#     'ackinger': 'a-form',
#     'ackja': 'a-form',
#     'ackjan': 'a-form',
#     'ackjefärd': 'a-form',
#     'acklamation': 'a-form',
#     'acklamationsval': 'a-form',
#     'ackland': 'a-form',
#     'acklid': 'a-form',
#     'acklimatisera': 'a-form',
#     'acklimatiserat': 'a-form',
#     'acklimatisering': 'a-form',
#     'acklin': 'a-form',
#     'ackling': 'a-form',
#     'acklingavägen': 'a-form',
#     'acklund': 'a-form',
#     'acklén': 'a-form',
#     'ackman': 'a-form',
#     'ackmark': 'a-form',
#     'ackommodation': 'a-form',
#     'ackommodationsförmåga': 'a-form',
#     'ackommodera': 'a-form',
#     'ackommodering': 'a-form',
#     'ackompanjatris': 'a-form',
#     'ackompanjatör': 'a-form',
#     'ackompanjemang': 'a-form',
#     'ackompanjemanget': 'a-form',
#     'ackompanjemangsinstrument': 'a-form',
#     'ackompanjera': 'a-form',
#     'ackompanjerad': 'a-form',
#     'ackompanjerade': 'a-form',
#     'ackompanjerades': 'a-form',
#     'ackompanjerande': 'a-form',
#     'ackompanjerar': 'a-form',
#     'ackompanjeras': 'a-form',
#     'ackompanjerat': 'a-form',
#     'ackompanjering': 'a-form',
#     'ackonius': 'a-form',
#     'ackord': 'a-form',
#     'ackordcentralen': 'a-form',
#     'ackorden': 'a-form',
#     'ackordet': 'a-form',
#     'ackordföljd': 'a-form',
#     'ackordisk': 'a-form',
#     'ackordsarbete': 'a-form',
#     'ackordsberäkn.': 'a-form',
#     'ackordsberäknare': 'a-form',
#     'ackordscentralen': 'a-form',
#     'ackordscentralens': 'a-form',
#     'ackordsförhandling': 'a-form',
#     'ackordshets': 'a-form',
#     'ackordsjobb': 'a-form',
#     'ackordsuppgörelse': 'a-form',
#     'ackreditera': 'a-form',
#     'ackrediterad': 'a-form',
#     'ackrediterade': 'a-form',
#     'ackreditering': 'a-form',
#     'ackrell': 'a-form',
#     'ackring': 'a-form',
#     'acktjärnsgatan': 'a-form',
#     'ackumulation': 'a-form',
#     'ackumulativ': 'a-form',
#     'ackumulatorer': 'a-form',
#     'ackumulera': 'a-form',
#     'ackumulerad': 'a-form',
#     'ackumulerade': 'a-form',
#     'ackumuleras': 'a-form',
#     'ackumulerat': 'a-form',
#     'ackurat': 'a-form',
#     'ackuratess': 'a-form',
#     'ackusativisk': 'a-form',
#     'ackuschörska': 'a-form',
#     'ackvirera': 'a-form',
#     'ackvirering': 'a-form',
#     'ackvis:r': 'a-form',
#     'ackvisition': 'a-form',
#     'ackvisitör': 'a-form',
#     'ackzell': 'a-form',
#     'ackzén': 'a-form',
#     'ackås': 'a-form',
#     'ackér': 'a-form',
#     'acne': 'a-form',
#     'aco': 'a-form',
#     'acosta': 'a-form',
#     'acryl': 'a-form',
#     'acs': 'a-form',
#     'action': 'a-form',
#     'actionfilm': 'a-form',
#     'actionfilmen': 'a-form',
#     'actionfilmer': 'a-form',
#     'actionhistoria': 'a-form',
#     'actionhjälten': 'a-form',
#     'actionkomedi': 'a-form',
#     'actionkomedier': 'a-form',
#     'actionscener': 'a-form',
#     'actionserie': 'a-form',
#     'actionsurf': 'a-form',
#     'acuna': 'a-form',
#     'ada': 'a-form',
#     'adagio': 'a-form',
#     'adak': 'a-form',
#     'adaktusson': 'a-form',
#     'adakvägen': 'a-form',
#     'adalbert': 'a-form',
#     'adalberth': 'a-form',
#     'adam': 'a-form',
#     'adama': 'a-form',
#     'adamczyk': 'a-form',
#     'adamek': 'a-form',
#     'adami': 'a-form',
#     'adamovic': 'a-form',
#     'adams': 'a-form',
#     'adams_väg': 'a-form',
#     'adamsdräkt': 'a-form',
#     'adamsen': 'a-form',
#     'adamsgatan': 'a-form',
#     'adamson': 'a-form',
#     'adamsson': 'a-form',
#     'adamstorpsvägen': 'a-form',
#     'adamsvägen': 'a-form',
#     'adamsäpple': 'a-form',
#     'adamsäpplet': 'a-form',
#     'adamzon': 'a-form',
#     'adan': 'a-form',
#     'adaptation': 'a-form',
#     'adapter': 'a-form',
#     'adaptera': 'a-form',
#     'adaptering': 'a-form',
#     'adaption': 'a-form',
#     'adaptiv': 'a-form',
#     'adaptiva': 'a-form',
#     'adar': 'a-form',
#     'adare': 'a-form',
#     'adauktusson': 'a-form',
#     'adawi': 'a-form',
#     'adb': 'a-form',
#     'adb-avtal': 'a-form',
#     'adb-chef': 'a-form',
#     'adb-enhet': 'a-form',
#     'adb-enheten': 'a-form',
#     'adb-enhetens': 'a-form',
#     'adb-funktionen': 'a-form',
#     'adb-funktionens': 'a-form',
#     'adb-gruppen': 'a-form',
#     'adb-kons.': 'a-form',
#     'adb-konsult': 'a-form',
#     'adb-kontoret': 'a-form',
#     'adb-kontorets': 'a-form',
#     'adb-man': 'a-form',
#     'adb-samordnarutbildning': 'a-form',
#     'adb-samordnarutbildningen': 'a-form',
#     'adb-system': 'a-form',
#     'adb-tekn.': 'a-form',
#     'adb-tekniker': 'a-form',
#     'adb-upptagningar': 'a-form',
#     'adberg': 'a-form',
#     'adbo': 'a-form',
#     'adborn': 'a-form',
#     'adbring': 'a-form',
#     'adbro': 'a-form',
#     'adbåge': 'a-form',
#     'addberger': 'a-form',
#     'addby': 'a-form',
#     'adde': 'a-form',
#     'addemark': 'a-form',
#     'addera': 'a-form',
#     'adderar': 'a-form',
#     'adderas': 'a-form',
#     'adderat': 'a-form',
#     'addering': 'a-form',
#     'addi': 'a-form',
#     'addie': 'a-form',
#     'addiktion': 'a-form',
#     'addin': 'a-form',
#     'adding': 'a-form',
#     'addison': 'a-form',
#     'addition': 'a-form',
#     'addukt': 'a-form',
#     'adduktion': 'a-form',
#     'addy': 'a-form',
#     'addén': 'a-form',
#     'ade': 'a-form',
#     'adebahr': 'a-form',
#     'adeberg': 'a-form',
#     'adebjörk': 'a-form',
#     'adebo': 'a-form',
#     'adeborg': 'a-form',
#     'adeborn': 'a-form',
#     'adebrant': 'a-form',
#     'adebratt': 'a-form',
#     'adebring': 'a-form',
#     'adebrink': 'a-form',
#     'adebro': 'a-form',
#     'adeby': 'a-form',
#     'adebäck': 'a-form',
#     'adebåge': 'a-form',
#     'adeen': 'a-form',
#     'adefalk': 'a-form',
#     'adefelt': 'a-form',
#     'adefjord': 'a-form',
#     'adefjärd': 'a-form',
#     'adefors': 'a-form',
#     'adegren': 'a-form',
#     'adegård': 'a-form',
#     'adehed': 'a-form',
#     'adeheimer': 'a-form',
#     'adeholm': 'a-form',
#     'adehorn': 'a-form',
#     'adehög': 'a-form',
#     'adeklint': 'a-form',
#     'adekvans': 'a-form',
#     'adekvat': 'a-form',
#     'adekvata': 'a-form',
#     'adel': 'a-form',
#     'adela': 'a-form',
#     'adelaide': 'a-form',
#     'adeland': 'a-form',
#     'adelavägen': 'a-form',
#     'adelback': 'a-form',
#     'adelbjer': 'a-form',
#     'adelborg': 'a-form',
#     'adelborgsvägen': 'a-form',
#     'adelbrand': 'a-form',
#     'adelbrant': 'a-form',
#     'adelbratt': 'a-form',
#     'adelby': 'a-form',
#     'adelbäck': 'a-form',
#     'adeldal': 'a-form',
#     'adele': 'a-form',
#     'adelfalk': 'a-form',
#     'adelgatan': 'a-form',
#     'adelgren': 'a-form',
#     'adelgård': 'a-form',
#     'adelhag': 'a-form',
#     'adelhammar': 'a-form',
#     'adelhed': 'a-form',
#     'adelheid': 'a-form',
#     'adelia': 'a-form',
#     'adelin': 'a-form',
#     'adelina': 'a-form',
#     'adelind': 'a-form',
#     'adeline': 'a-form',
#     'adelius': 'a-form',
#     'adeljung': 'a-form',
#     'adell': 'a-form',
#     'adelman': 'a-form',
#     'adelmar': 'a-form',
#     'adelmyr': 'a-form',
#     'adeln': 'a-form',
#     'adelns': 'a-form',
#     'adelros': 'a-form',
#     'adelrydh': 'a-form',
#     'adelsberg': 'a-form',
#     'adelsberger': 'a-form',
#     'adelsbergsvägen': 'a-form',
#     'adelsdam': 'a-form',
#     'adelsdottern': 'a-form',
#     'adelsfamilj': 'a-form',
#     'adelsgatan': 'a-form',
#     'adelsgård': 'a-form',
#     'adelsjö': 'a-form',
#     'adelskalendern': 'a-form',
#     'adelskap': 'a-form',
#     'adelskapet': 'a-form',
#     'adelskogh': 'a-form',
#     'adelsköld': 'a-form',
#     'adelsköldsgatan': 'a-form',
#     'adelsman': 'a-form',
#     'adelsmannen': 'a-form',
#     'adelsmannens': 'a-form',
#     'adelsmans': 'a-form',
#     'adelsmark': 'a-form',
#     'adelsmän': 'a-form',
#     'adelsmännen': 'a-form',
#     'adelsmärke': 'a-form',
#     'adelsnäs': 'a-form',
#     'adelsnäsvägen': 'a-form',
#     'adelsohn': 'a-form',
#     'adelson': 'a-form',
#     'adelsson': 'a-form',
#     'adelstam': 'a-form',
#     'adelsten': 'a-form',
#     'adelstitel': 'a-form',
#     'adelstokige': 'a-form',
#     'adelstorpsvägen': 'a-form',
#     'adelstrand': 'a-form',
#     'adelståhl': 'a-form',
#     'adelstål': 'a-form',
#     'adelsund': 'a-form',
#     'adelsvälde': 'a-form',
#     'adelsvärd': 'a-form',
#     'adelswärd': 'a-form',
#     'adelswärdsgatan': 'a-form',
#     'adelswärdsvägen': 'a-form',
#     'adelsö': 'a-form',
#     'adelsögatan': 'a-form',
#     'adelé': 'a-form',
#     'adelöf': 'a-form',
#     'adelöv': 'a-form',
#     'adelövägen': 'a-form',
#     'adelöw': 'a-form',
#     'adem': 'a-form',
#     'ademaj': 'a-form',
#     'ademan': 'a-form',
#     'ademar': 'a-form',
#     'ademark': 'a-form',
#     'ademi': 'a-form',
#     'ademyr': 'a-form',
#     'aden': 'a-form',
#     'adenauer': 'a-form',
#     'adenberg': 'a-form',
#     'adenborg': 'a-form',
#     'adenbrandt': 'a-form',
#     'adenbrant': 'a-form',
#     'adenbring': 'a-form',
#     'adenby': 'a-form',
#     'adenbäck': 'a-form',
#     'adenfalk': 'a-form',
#     'adenfelt': 'a-form',
#     'adenfors': 'a-form',
#     'adengård': 'a-form',
#     'adenholm': 'a-form',
#     'adenius': 'a-form',
#     'adenkrans': 'a-form',
#     'adenkrantz': 'a-form',
#     'adenling': 'a-form',
#     'adenlöf': 'a-form',
#     'adenmark': 'a-form',
#     'adensjö': 'a-form',
#     'adenskog': 'a-form',
#     'adenstam': 'a-form',
#     'adenstedt': 'a-form',
#     'adenvall': 'a-form',
#     'adenwall': 'a-form',
#     'adenäs': 'a-form',
#     'adenås': 'a-form',
#     'adept': 'a-form',
#     'adepter': 'a-form',
#     'ader': 'a-form',
#     'aderby': 'a-form',
#     'aderfelt': 'a-form',
#     'aderfors': 'a-form',
#     'aderheim': 'a-form',
#     'aderklint': 'a-form',
#     'aderlind': 'a-form',
#     'aderling': 'a-form',
#     'aderlund': 'a-form',
#     'adermalm': 'a-form',
#     'aderman': 'a-form',
#     'adermark': 'a-form',
#     'aderot': 'a-form',
#     'aderoth': 'a-form',
#     'adersjö': 'a-form',
#     'aderskog': 'a-form',
#     'aderstedt': 'a-form',
#     'adersten': 'a-form',
#     'aderstål': 'a-form',
#     'aderth': 'a-form',
#     'aderton': 'a-form',
#     ...}}),
#  (('models/DeepPhon/winhome/Downloads/DeepPhon_to_send/best_model.pt',),
#   {'accuracy': 0.0,
#    'output_dict': {'a': 'a-form',
#     'a-aktier': 'a-form',
#     'a-banan': 'a-form',
#     'a-ekonomi': 'a-form',
#     'a-et': 'a-form',
#     'a-final': 'a-form',
#     'a-finalen': 'a-form',
#     'a-flyg': 'a-form',
#     'a-form': 'a-form',
#     'a-gruppen': 'a-form',
#     'a-juniorer': 'a-form',
#     'a-juniorerna': 'a-form',
#     'a-juniorlaget': 'a-form',
#     'a-kamper': 'a-form',
#     'a-kassa': 'a-form',
#     'a-kassan': 'a-form',
#     'a-kassor': 'a-form',
#     'a-kassorna': 'a-form',
#     'a-lag': 'a-form',
#     'a-lagare': 'a-form',
#     'a-lagarna': 'a-form',
#     'a-laget': 'a-form',
#     'a-lagets': 'a-form',
#     'a-lagsjuniorerna': 'a-form',
#     'a-lagspelare': 'a-form',
#     'a-lagsspelare': 'a-form',
#     'a-landskamper': 'a-form',
#     'a-landslag': 'a-form',
#     'a-landslaget': 'a-form',
#     'a-listan': 'a-form',
#     'a-ljud': 'a-form',
#     'a-ljudet': 'a-form',
#     'a-n': 'a-form',
#     'a-nummer': 'a-form',
#     'a-pojke': 'a-form',
#     'a-pressen': 'a-form',
#     'a-pressens': 'a-form',
#     'a-presskoncernens': 'a-form',
#     'a-presstidningar': 'a-form',
#     'a-presstidningarna': 'a-form',
#     'a-provet': 'a-form',
#     'a-trupp': 'a-form',
#     'a-truppen': 'a-form',
#     'a-tur': 'a-form',
#     'a-vitamin': 'a-form',
#     'a-vitaminliknande': 'a-form',
#     'a:son': 'a-form',
#     'a_a': 'a-form',
#     'a_b_c_gatan': 'a-form',
#     'a_bergmans_väg': 'a-form',
#     'a_c_lindblads_gata': 'a-form',
#     'a_e_holmbergs_gata': 'a-form',
#     'a_f_håkanssons_väg': 'a-form',
#     'a_odhners_gata': 'a-form',
#     'a_p_sjöbergs_väg': 'a-form',
#     'aabel': 'a-form',
#     'aaben': 'a-form',
#     'aaby': 'a-form',
#     'aadde': 'a-form',
#     'aadel': 'a-form',
#     'aadland': 'a-form',
#     'aadli': 'a-form',
#     'aadu': 'a-form',
#     'aadén': 'a-form',
#     'aagaard': 'a-form',
#     'aage': 'a-form',
#     'aagesen': 'a-form',
#     'aagesson': 'a-form',
#     'aagot': 'a-form',
#     'aagots': 'a-form',
#     'aahlborg': 'a-form',
#     'aaker': 'a-form',
#     'aakerholm': 'a-form',
#     'aakre': 'a-form',
#     'aalbers': 'a-form',
#     'aalborg': 'a-form',
#     'aalerud': 'a-form',
#     'aall': 'a-form',
#     'aalstad': 'a-form',
#     'aalsö': 'a-form',
#     'aalto': 'a-form',
#     'aalto-vasen': 'a-form',
#     'aaltonen': 'a-form',
#     'aalvik': 'a-form',
#     'aaman': 'a-form',
#     'aamisepp': 'a-form',
#     'aamlid': 'a-form',
#     'aamodt': 'a-form',
#     'aandahl': 'a-form',
#     'aandstad': 'a-form',
#     'aanerud': 'a-form',
#     'aanesen': 'a-form',
#     'aanstad': 'a-form',
#     'aapo': 'a-form',
#     'aardal': 'a-form',
#     'aare': 'a-form',
#     'aarea': 'a-form',
#     'aarenstrup': 'a-form',
#     'aarflot': 'a-form',
#     'aarholdt': 'a-form',
#     'aarhus': 'a-form',
#     'aarna': 'a-form',
#     'aarne': 'a-form',
#     'aarni': 'a-form',
#     'aarnio': 'a-form',
#     'aarno': 'a-form',
#     'aarnseth': 'a-form',
#     'aaro': 'a-form',
#     'aaron': 'a-form',
#     'aarons': 'a-form',
#     'aarre': 'a-form',
#     'aarseth': 'a-form',
#     'aarskog': 'a-form',
#     'aarsrud': 'a-form',
#     'aarstad': 'a-form',
#     'aarto': 'a-form',
#     'aartola': 'a-form',
#     'aarvidsson': 'a-form',
#     'aarås': 'a-form',
#     'aaröe': 'a-form',
#     'aas': 'a-form',
#     'aasa': 'a-form',
#     'aasberg': 'a-form',
#     'aase': 'a-form',
#     'aasen': 'a-form',
#     'aasgaard': 'a-form',
#     'aasgård': 'a-form',
#     'aasheim': 'a-form',
#     'aasland': 'a-form',
#     'aaslund': 'a-form',
#     'aasma': 'a-form',
#     'aasmundsen': 'a-form',
#     'aastradsen': 'a-form',
#     'aastrup': 'a-form',
#     'aate': 'a-form',
#     'aatos': 'a-form',
#     'aatto': 'a-form',
#     'aava': 'a-form',
#     'aavik': 'a-form',
#     'ab': 'a-form',
#     'abadi': 'a-form',
#     'abarca': 'a-form',
#     'abassi': 'a-form',
#     'abba': 'a-form',
#     'abbas': 'a-form',
#     'abbasi': 'a-form',
#     'abbassi': 'a-form',
#     'abbe': 'a-form',
#     'abbedissa': 'a-form',
#     'abbedissan': 'a-form',
#     'abbedissans': 'a-form',
#     'abbedissavägen': 'a-form',
#     'abbedissgatan': 'a-form',
#     'abbefalk': 'a-form',
#     'abbefors': 'a-form',
#     'abbegren': 'a-form',
#     'abbegård': 'a-form',
#     'abbekås': 'a-form',
#     'abbekåsgatan': 'a-form',
#     'abbeling': 'a-form',
#     'abbemalm': 'a-form',
#     'abbemark': 'a-form',
#     'abben': 'a-form',
#     'abberud': 'a-form',
#     'abberyd': 'a-form',
#     'abbesjö': 'a-form',
#     'abbestam': 'a-form',
#     'abbesten': 'a-form',
#     'abbetoft': 'a-form',
#     'abbevik': 'a-form',
#     'abbhagen': 'a-form',
#     'abbhammar': 'a-form',
#     'abbhed': 'a-form',
#     'abbing': 'a-form',
#     'abbor': 'a-form',
#     'abborrar': 'a-form',
#     'abborrarna': 'a-form',
#     'abborrart': 'a-form',
#     'abborrartad': 'a-form',
#     'abborre': 'a-form',
#     'abborrebergsvägen': 'a-form',
#     'abborregatan': 'a-form',
#     'abborren': 'a-form',
#     'abborrestigen': 'a-form',
#     'abborrevägen': 'a-form',
#     'abborrfisk': 'a-form',
#     'abborrfiske': 'a-form',
#     'abborrgatan': 'a-form',
#     'abborrgrund': 'a-form',
#     'abborrgränd': 'a-form',
#     'abborrkroken': 'a-form',
#     'abborrmunnen': 'a-form',
#     'abborrpinne': 'a-form',
#     'abborrstigen': 'a-form',
#     'abborrtjärnsvägen': 'a-form',
#     'abborrtorpsvägen': 'a-form',
#     'abborrträsk': 'a-form',
#     'abborrvägen': 'a-form',
#     'abbot': 'a-form',
#     'abboten': 'a-form',
#     'abbotens': 'a-form',
#     'abbotens_väg': 'a-form',
#     'abbotsdöme': 'a-form',
#     'abbotsgatan': 'a-form',
#     'abbotskap': 'a-form',
#     'abbotvägen': 'a-form',
#     'abboud': 'a-form',
#     'abbreviation': 'a-form',
#     'abbreviatur': 'a-form',
#     'abbreviera': 'a-form',
#     'abbreviering': 'a-form',
#     'abbås': 'a-form',
#     'abbé': 'a-form',
#     'abc': 'a-form',
#     'abc-bok': 'a-form',
#     'abc-boken': 'a-form',
#     'abc-nytt': 'a-form',
#     'abd': 'a-form',
#     'abda': 'a-form',
#     'abdalla': 'a-form',
#     'abdallah': 'a-form',
#     'abdel': 'a-form',
#     'abdelahad': 'a-form',
#     'abdelaziz': 'a-form',
#     'abdelkader': 'a-form',
#     'abdellah': 'a-form',
#     'abdellatif': 'a-form',
#     'abderit': 'a-form',
#     'abderitisk': 'a-form',
#     'abderrahmane': 'a-form',
#     'abdeslam': 'a-form',
#     'abdi': 'a-form',
#     'abdikarim': 'a-form',
#     'abdikation': 'a-form',
#     'abdikationsakt': 'a-form',
#     'abdikera': 'a-form',
#     'abdikerade': 'a-form',
#     'abdikerar': 'a-form',
#     'abdikerat': 'a-form',
#     'abdikering': 'a-form',
#     'abdillahi': 'a-form',
#     'abdirahman': 'a-form',
#     'abdirizak': 'a-form',
#     'abdo': 'a-form',
#     'abdol': 'a-form',
#     'abdolhossein': 'a-form',
#     'abdollah': 'a-form',
#     'abdollahi': 'a-form',
#     'abdolreza': 'a-form',
#     'abdomen': 'a-form',
#     'abdominala': 'a-form',
#     'abdon': 'a-form',
#     'abdu': 'a-form',
#     'abduktiv': 'a-form',
#     'abdul': 'a-form',
#     'abdulah': 'a-form',
#     'abdulahad': 'a-form',
#     'abdulaziz': 'a-form',
#     'abdulhadi': 'a-form',
#     'abdulhamid': 'a-form',
#     'abdulkader': 'a-form',
#     'abdulkadir': 'a-form',
#     'abdulkarim': 'a-form',
#     'abdulkerim': 'a-form',
#     'abdulla': 'a-form',
#     'abdullah': 'a-form',
#     'abdullahad': 'a-form',
#     'abdullahi': 'a-form',
#     'abdulle': 'a-form',
#     'abdulmasih': 'a-form',
#     'abdulmesih': 'a-form',
#     'abdulrahman': 'a-form',
#     'abdulsalam': 'a-form',
#     'abdurahman': 'a-form',
#     'abeba': 'a-form',
#     'abebe': 'a-form',
#     'abed': 'a-form',
#     'abedal': 'a-form',
#     'abedi': 'a-form',
#     'abedian': 'a-form',
#     'abedin': 'a-form',
#     'abefelt': 'a-form',
#     'abefors': 'a-form',
#     'abel': 'a-form',
#     'abel_beckers_gata': 'a-form',
#     'abeleen': 'a-form',
#     'abelin': 'a-form',
#     'abeling': 'a-form',
#     'abelius': 'a-form',
#     'abelli': 'a-form',
#     'abeln': 'a-form',
#     'abelson': 'a-form',
#     'abelsson': 'a-form',
#     'abelt': 'a-form',
#     'abeman': 'a-form',
#     'aben': 'a-form',
#     'abenius': 'a-form',
#     'aber': 'a-form',
#     'abergavägen': 'a-form',
#     'aberger': 'a-form',
#     'aberin': 'a-form',
#     'aberius': 'a-form',
#     'aberration': 'a-form',
#     'abersten': 'a-form',
#     'aberén': 'a-form',
#     'abessinsk': 'a-form',
#     'abessinska': 'a-form',
#     'abi': 'a-form',
#     'abid': 'a-form',
#     'abidi': 'a-form',
#     'abilitet': 'a-form',
#     'abin': 'a-form',
#     'abir': 'a-form',
#     'abisko': 'a-form',
#     'abiskoområdet': 'a-form',
#     'abiskovägen': 'a-form',
#     'abjörnssons_väg': 'a-form',
#     'abjörnssonsvägen': 'a-form',
#     'ablahad': 'a-form',
#     'ablation': 'a-form',
#     'ablativ': 'a-form',
#     'ablativform': 'a-form',
#     'abler': 'a-form',
#     'abmorvägen': 'a-form',
#     'abnell': 'a-form',
#     'abner': 'a-form',
#     'abnorm': 'a-form',
#     'abnorma': 'a-form',
#     'abnormitet': 'a-form',
#     'abnormitetens': 'a-form',
#     'abnormiteter': 'a-form',
#     'abnormt': 'a-form',
#     'abnormtillstånd': 'a-form',
#     'abolfazl': 'a-form',
#     'abolghasem': 'a-form',
#     'abolins': 'a-form',
#     'abolition': 'a-form',
#     'abonius': 'a-form',
#     'abonnemang': 'a-form',
#     'abonnemangen': 'a-form',
#     'abonnemanget': 'a-form',
#     'abonnemangsavgiften': 'a-form',
#     'abonnemangsavtal': 'a-form',
#     'abonnemangsbyte': 'a-form',
#     'abonnemangserbjudande': 'a-form',
#     'abonnemangsfritt': 'a-form',
#     'abonnemangsfråga': 'a-form',
#     'abonnemangsfrågor': 'a-form',
#     'abonnemangskonserterna': 'a-form',
#     'abonnemangsnummer': 'a-form',
#     'abonnemangspris': 'a-form',
#     'abonnent': 'a-form',
#     'abonnenten': 'a-form',
#     'abonnenter': 'a-form',
#     'abonnenterna': 'a-form',
#     'abonnentskaran': 'a-form',
#     'abonnera': 'a-form',
#     'abonnerad': 'a-form',
#     'abonnerade': 'a-form',
#     'abonnerar': 'a-form',
#     'abonnerat': 'a-form',
#     'aboriginer': 'a-form',
#     'aboriginerna': 'a-form',
#     'aborrvägen': 'a-form',
#     'abort': 'a-form',
#     'aborten': 'a-form',
#     'aborter': 'a-form',
#     'abortera': 'a-form',
#     'aborterade': 'a-form',
#     'aborterna': 'a-form',
#     'abortframkallande': 'a-form',
#     'abortframkallare': 'a-form',
#     'abortfråga': 'a-form',
#     'abortfrågan': 'a-form',
#     'abortförbud': 'a-form',
#     'abortförebyggande': 'a-form',
#     'abortingreppet': 'a-form',
#     'abortiv': 'a-form',
#     'abortklinik': 'a-form',
#     'abortkliniker': 'a-form',
#     'abortlag': 'a-form',
#     'abortlagen': 'a-form',
#     'abortlagstiftning': 'a-form',
#     'abortlagstiftningen': 'a-form',
#     'abortmotståndare': 'a-form',
#     'abortmotståndarna': 'a-form',
#     'abortpiller': 'a-form',
#     'abortpillret': 'a-form',
#     'abortresa': 'a-form',
#     'aborträtten': 'a-form',
#     'abortrådgivning': 'a-form',
#     'abortsökande': 'a-form',
#     'abortör': 'a-form',
#     'abou': 'a-form',
#     'aboud': 'a-form',
#     'abradera': 'a-form',
#     'abradering': 'a-form',
#     'abraha': 'a-form',
#     'abraham': 'a-form',
#     'abraham_ahléns_väg': 'a-form',
#     'abraham_bäckgatan': 'a-form',
#     'abrahams': 'a-form',
#     'abrahamsberg': 'a-form',
#     'abrahamsbergsvägen': 'a-form',
#     'abrahamsbovägen': 'a-form',
#     'abrahamsen': 'a-form',
#     'abrahamson': 'a-form',
#     'abrahamsson': 'a-form',
#     'abrahamsvägen': 'a-form',
#     'abrahim': 'a-form',
#     'abrahmson': 'a-form',
#     'abrahmsson': 'a-form',
#     'abrahmsén': 'a-form',
#     'abrakadabra': 'a-form',
#     'abram': 'a-form',
#     'abramsgård': 'a-form',
#     'abramson': 'a-form',
#     'abramsson': 'a-form',
#     'abramsvägen': 'a-form',
#     'abrasion': 'a-form',
#     'abrasionsbrant': 'a-form',
#     'abrehet': 'a-form',
#     'abrell': 'a-form',
#     'abresparr': 'a-form',
#     'abreu': 'a-form',
#     'abring': 'a-form',
#     'abrupt': 'a-form',
#     'abrupta': 'a-form',
#     'absalons_väg': 'a-form',
#     'absens': 'a-form',
#     'abshir': 'a-form',
#     'absid': 'a-form',
#     'absidgatan': 'a-form',
#     'absidkyrka': 'a-form',
#     'absint': 'a-form',
#     'absintflaska': 'a-form',
#     'abskissa': 'a-form',
#     'absolut': 'a-form',
#     'absoluta': 'a-form',
#     'absolute': 'a-form',
#     'absolutflaskan': 'a-form',
#     'absolution': 'a-form',
#     'absolutism': 'a-form',
#     'absolutist': 'a-form',
#     'absolutisterna': 'a-form',
#     'absolutistisk': 'a-form',
#     'absolvera': 'a-form',
#     'absolvering': 'a-form',
#     'absorbera': 'a-form',
#     'absorberad': 'a-form',
#     'absorberade': 'a-form',
#     'absorberar': 'a-form',
#     'absorberas': 'a-form',
#     'absorberat': 'a-form',
#     'absorberats': 'a-form',
#     'absorption': 'a-form',
#     'absorptionen': 'a-form',
#     'absorptionsband': 'a-form',
#     'absorptionsförmåga': 'a-form',
#     'abstinens': 'a-form',
#     'abstinensbesvär': 'a-form',
#     'abstinenseffekter': 'a-form',
#     'abstract': 'a-form',
#     'abstrahera': 'a-form',
#     'abstraherande': 'a-form',
#     'abstrahering': 'a-form',
#     'abstrakt': 'a-form',
#     'abstrakta': 'a-form',
#     'abstraktion': 'a-form',
#     'abstraktionen': 'a-form',
#     'abstraktionens': 'a-form',
#     'abstraktioner': 'a-form',
#     'abstraktionsförmåga': 'a-form',
#     'abstraktionsnivå': 'a-form',
#     'abstraktionssynen': 'a-form',
#     'abstrus': 'a-form',
#     'absurd': 'a-form',
#     'absurda': 'a-form',
#     'absurdhet': 'a-form',
#     'absurdism': 'a-form',
#     'absurdismen': 'a-form',
#     'absurdist': 'a-form',
#     'absurdisterna': 'a-form',
#     'absurdistisk': 'a-form',
#     'absurdistiska': 'a-form',
#     'absurditet': 'a-form',
#     'absurditetens': 'a-form',
#     'absurditeter': 'a-form',
#     'absurdum': 'a-form',
#     'absurt': 'a-form',
#     'abtin': 'a-form',
#     'abu': 'a-form',
#     'abul': 'a-form',
#     'abundans': 'a-form',
#     'abundant': 'a-form',
#     'abus': 'a-form',
#     'abwin': 'a-form',
#     'abygatan': 'a-form',
#     'abyssal': 'a-form',
#     'abäcksvägen': 'a-form',
#     'acar': 'a-form',
#     'accedera': 'a-form',
#     'acceleration': 'a-form',
#     'accelerationen': 'a-form',
#     'accelerationssträcka': 'a-form',
#     'accelerator': 'a-form',
#     'acceleratorer': 'a-form',
#     'acceleratorerna': 'a-form',
#     'acceleratorernas': 'a-form',
#     'acceleratorn': 'a-form',
#     'accelerera': 'a-form',
#     'accelererade': 'a-form',
#     'accelererades': 'a-form',
#     'accelererande': 'a-form',
#     'accelererar': 'a-form',
#     'accelereras': 'a-form',
#     'accelererat': 'a-form',
#     'accelerering': 'a-form',
#     'accent': 'a-form',
#     'accenten': 'a-form',
#     'accenter': 'a-form',
#     'accentuera': 'a-form',
#     'accentuerad': 'a-form',
#     'accentuerade': 'a-form',
#     'accentuerades': 'a-form',
#     'accentuerar': 'a-form',
#     'accentueras': 'a-form',
#     'accentuerat': 'a-form',
#     'accentuerats': 'a-form',
#     'accentuering': 'a-form',
#     'accept': 'a-form',
#     'acceptabel': 'a-form',
#     'acceptabelt': 'a-form',
#     'acceptabla': 'a-form',
#     'acceptans': 'a-form',
#     'acceptansen': 'a-form',
#     'accepten': 'a-form',
#     'acceptera': 'a-form',
#     'accepterad': 'a-form',
#     'accepterade': 'a-form',
#     'accepterades': 'a-form',
#     'accepterande': 'a-form',
#     'accepterandet': 'a-form',
#     'accepterar': 'a-form',
#     'accepteras': 'a-form',
#     'accepterat': 'a-form',
#     'accepterats': 'a-form',
#     'access': 'a-form',
#     'accessoar': 'a-form',
#     'accessoarer': 'a-form',
#     'accesstjänster': 'a-form',
#     'accis': 'a-form',
#     'accisfri': 'a-form',
#     'accismedel': 'a-form',
#     'accispliktig': 'a-form',
#     'acetat': 'a-form',
#     'acetatsilke': 'a-form',
#     'aceton': 'a-form',
#     'acetylen': 'a-form',
#     'acetylengas': 'a-form',
#     'acetylenlampa': 'a-form',
#     'acetylsalicylsyra': 'a-form',
#     'acevedo': 'a-form',
#     'achilleas': 'a-form',
#     'achim': 'a-form',
#     'achmed': 'a-form',
#     'achour': 'a-form',
#     'achrén': 'a-form',
#     'achteenberg': 'a-form',
#     'achtenberg': 'a-form',
#     'achtman': 'a-form',
#     'aciditet': 'a-form',
#     'ack': 'a-form',
#     'ackalin': 'a-form',
#     'ackberger': 'a-form',
#     'acke': 'a-form',
#     'ackeberg': 'a-form',
#     'ackebjer': 'a-form',
#     'ackebo': 'a-form',
#     'ackeborn': 'a-form',
#     'ackebrink': 'a-form',
#     'ackeby': 'a-form',
#     'ackedahl': 'a-form',
#     'ackefelt': 'a-form',
#     'ackefjord': 'a-form',
#     'ackefors': 'a-form',
#     'ackegård': 'a-form',
#     'ackehed': 'a-form',
#     'ackelid': 'a-form',
#     'ackelin': 'a-form',
#     'ackelind': 'a-form',
#     'ackell': 'a-form',
#     'ackelman': 'a-form',
#     'ackelöv': 'a-form',
#     'ackemalm': 'a-form',
#     'ackemar': 'a-form',
#     'ackemark': 'a-form',
#     'ackemo': 'a-form',
#     'ackenäs': 'a-form',
#     'ackerberg': 'a-form',
#     'ackerblad': 'a-form',
#     'ackerborg': 'a-form',
#     'ackerby': 'a-form',
#     'ackerdahl': 'a-form',
#     'ackerdal': 'a-form',
#     'ackered': 'a-form',
#     'ackerfeldt': 'a-form',
#     'ackerfors': 'a-form',
#     'ackerhans': 'a-form',
#     'ackerholm': 'a-form',
#     'ackerholt': 'a-form',
#     'ackerhus': 'a-form',
#     'ackerman': 'a-form',
#     'ackermann': 'a-form',
#     'ackermark': 'a-form',
#     'ackerot': 'a-form',
#     'ackers': 'a-form',
#     'ackerstedt': 'a-form',
#     'ackerstierna': 'a-form',
#     'ackerstig': 'a-form',
#     'ackerstrand': 'a-form',
#     'ackerud': 'a-form',
#     'ackerup': 'a-form',
#     'ackeryd': 'a-form',
#     'ackesjö': 'a-form',
#     'ackeskog': 'a-form',
#     'ackesten': 'a-form',
#     'ackestig': 'a-form',
#     'ackeström': 'a-form',
#     'ackeståhl': 'a-form',
#     'ackestål': 'a-form',
#     'acketoft': 'a-form',
#     'ackevall': 'a-form',
#     'ackevik': 'a-form',
#     'ackewald': 'a-form',
#     'ackfeldt': 'a-form',
#     'ackfjäll': 'a-form',
#     'ackfjärd': 'a-form',
#     'ackhammar': 'a-form',
#     'ackheden': 'a-form',
#     'acki': 'a-form',
#     'acking': 'a-form',
#     'ackinger': 'a-form',
#     'ackja': 'a-form',
#     'ackjan': 'a-form',
#     'ackjefärd': 'a-form',
#     'acklamation': 'a-form',
#     'acklamationsval': 'a-form',
#     'ackland': 'a-form',
#     'acklid': 'a-form',
#     'acklimatisera': 'a-form',
#     'acklimatiserat': 'a-form',
#     'acklimatisering': 'a-form',
#     'acklin': 'a-form',
#     'ackling': 'a-form',
#     'acklingavägen': 'a-form',
#     'acklund': 'a-form',
#     'acklén': 'a-form',
#     'ackman': 'a-form',
#     'ackmark': 'a-form',
#     'ackommodation': 'a-form',
#     'ackommodationsförmåga': 'a-form',
#     'ackommodera': 'a-form',
#     'ackommodering': 'a-form',
#     'ackompanjatris': 'a-form',
#     'ackompanjatör': 'a-form',
#     'ackompanjemang': 'a-form',
#     'ackompanjemanget': 'a-form',
#     'ackompanjemangsinstrument': 'a-form',
#     'ackompanjera': 'a-form',
#     'ackompanjerad': 'a-form',
#     'ackompanjerade': 'a-form',
#     'ackompanjerades': 'a-form',
#     'ackompanjerande': 'a-form',
#     'ackompanjerar': 'a-form',
#     'ackompanjeras': 'a-form',
#     'ackompanjerat': 'a-form',
#     'ackompanjering': 'a-form',
#     'ackonius': 'a-form',
#     'ackord': 'a-form',
#     'ackordcentralen': 'a-form',
#     'ackorden': 'a-form',
#     'ackordet': 'a-form',
#     'ackordföljd': 'a-form',
#     'ackordisk': 'a-form',
#     'ackordsarbete': 'a-form',
#     'ackordsberäkn.': 'a-form',
#     'ackordsberäknare': 'a-form',
#     'ackordscentralen': 'a-form',
#     'ackordscentralens': 'a-form',
#     'ackordsförhandling': 'a-form',
#     'ackordshets': 'a-form',
#     'ackordsjobb': 'a-form',
#     'ackordsuppgörelse': 'a-form',
#     'ackreditera': 'a-form',
#     'ackrediterad': 'a-form',
#     'ackrediterade': 'a-form',
#     'ackreditering': 'a-form',
#     'ackrell': 'a-form',
#     'ackring': 'a-form',
#     'acktjärnsgatan': 'a-form',
#     'ackumulation': 'a-form',
#     'ackumulativ': 'a-form',
#     'ackumulatorer': 'a-form',
#     'ackumulera': 'a-form',
#     'ackumulerad': 'a-form',
#     'ackumulerade': 'a-form',
#     'ackumuleras': 'a-form',
#     'ackumulerat': 'a-form',
#     'ackurat': 'a-form',
#     'ackuratess': 'a-form',
#     'ackusativisk': 'a-form',
#     'ackuschörska': 'a-form',
#     'ackvirera': 'a-form',
#     'ackvirering': 'a-form',
#     'ackvis:r': 'a-form',
#     'ackvisition': 'a-form',
#     'ackvisitör': 'a-form',
#     'ackzell': 'a-form',
#     'ackzén': 'a-form',
#     'ackås': 'a-form',
#     'ackér': 'a-form',
#     'acne': 'a-form',
#     'aco': 'a-form',
#     'acosta': 'a-form',
#     'acryl': 'a-form',
#     'acs': 'a-form',
#     'action': 'a-form',
#     'actionfilm': 'a-form',
#     'actionfilmen': 'a-form',
#     'actionfilmer': 'a-form',
#     'actionhistoria': 'a-form',
#     'actionhjälten': 'a-form',
#     'actionkomedi': 'a-form',
#     'actionkomedier': 'a-form',
#     'actionscener': 'a-form',
#     'actionserie': 'a-form',
#     'actionsurf': 'a-form',
#     'acuna': 'a-form',
#     'ada': 'a-form',
#     'adagio': 'a-form',
#     'adak': 'a-form',
#     'adaktusson': 'a-form',
#     'adakvägen': 'a-form',
#     'adalbert': 'a-form',
#     'adalberth': 'a-form',
#     'adam': 'a-form',
#     'adama': 'a-form',
#     'adamczyk': 'a-form',
#     'adamek': 'a-form',
#     'adami': 'a-form',
#     'adamovic': 'a-form',
#     'adams': 'a-form',
#     'adams_väg': 'a-form',
#     'adamsdräkt': 'a-form',
#     'adamsen': 'a-form',
#     'adamsgatan': 'a-form',
#     'adamson': 'a-form',
#     'adamsson': 'a-form',
# ...
#     'abrahim': 'a-form',
#     'abrahmson': 'a-form',
#     'abrahmsson': 'a-form',
#     'abrahmsén': 'a-form',
#     'abrakadabra': 'a-form',
#     'abram': 'a-form',
#     'abramsgård': 'a-form',
#     'abramson': 'a-form',
#     'abramsson': 'a-form',
#     'abramsvägen': 'a-form',
#     'abrasion': 'a-form',
#     'abrasionsbrant': 'a-form',
#     'abrehet': 'a-form',
#     'abrell': 'a-form',
#     'abresparr': 'a-form',
#     'abreu': 'a-form',
#     'abring': 'a-form',
#     'abrupt': 'a-form',
#     'abrupta': 'a-form',
#     'absalons_väg': 'a-form',
#     'absens': 'a-form',
#     'abshir': 'a-form',
#     'absid': 'a-form',
#     'absidgatan': 'a-form',
#     'absidkyrka': 'a-form',
#     'absint': 'a-form',
#     'absintflaska': 'a-form',
#     'abskissa': 'a-form',
#     'absolut': 'a-form',
#     'absoluta': 'a-form',
#     'absolute': 'a-form',
#     'absolutflaskan': 'a-form',
#     'absolution': 'a-form',
#     'absolutism': 'a-form',
#     'absolutist': 'a-form',
#     'absolutisterna': 'a-form',
#     'absolutistisk': 'a-form',
#     'absolvera': 'a-form',
#     'absolvering': 'a-form',
#     'absorbera': 'a-form',
#     'absorberad': 'a-form',
#     'absorberade': 'a-form',
#     'absorberar': 'a-form',
#     'absorberas': 'a-form',
#     'absorberat': 'a-form',
#     'absorberats': 'a-form',
#     'absorption': 'a-form',
#     'absorptionen': 'a-form',
#     'absorptionsband': 'a-form',
#     'absorptionsförmåga': 'a-form',
#     'abstinens': 'a-form',
#     'abstinensbesvär': 'a-form',
#     'abstinenseffekter': 'a-form',
#     'abstract': 'a-form',
#     'abstrahera': 'a-form',
#     'abstraherande': 'a-form',
#     'abstrahering': 'a-form',
#     'abstrakt': 'a-form',
#     'abstrakta': 'a-form',
#     'abstraktion': 'a-form',
#     'abstraktionen': 'a-form',
#     'abstraktionens': 'a-form',
#     'abstraktioner': 'a-form',
#     'abstraktionsförmåga': 'a-form',
#     'abstraktionsnivå': 'a-form',
#     'abstraktionssynen': 'a-form',
#     'abstrus': 'a-form',
#     'absurd': 'a-form',
#     'absurda': 'a-form',
#     'absurdhet': 'a-form',
#     'absurdism': 'a-form',
#     'absurdismen': 'a-form',
#     'absurdist': 'a-form',
#     'absurdisterna': 'a-form',
#     'absurdistisk': 'a-form',
#     'absurdistiska': 'a-form',
#     'absurditet': 'a-form',
#     'absurditetens': 'a-form',
#     'absurditeter': 'a-form',
#     'absurdum': 'a-form',
#     'absurt': 'a-form',
#     'abtin': 'a-form',
#     'abu': 'a-form',
#     'abul': 'a-form',
#     'abundans': 'a-form',
#     'abundant': 'a-form',
#     'abus': 'a-form',
#     'abwin': 'a-form',
#     'abygatan': 'a-form',
#     'abyssal': 'a-form',
#     'abäcksvägen': 'a-form',
#     'acar': 'a-form',
#     'accedera': 'a-form',
#     'acceleration': 'a-form',
#     'accelerationen': 'a-form',
#     'accelerationssträcka': 'a-form',
#     'accelerator': 'a-form',
#     'acceleratorer': 'a-form',
#     'acceleratorerna': 'a-form',
#     'acceleratorernas': 'a-form',
#     'acceleratorn': 'a-form',
#     'accelerera': 'a-form',
#     'accelererade': 'a-form',
#     'accelererades': 'a-form',
#     'accelererande': 'a-form',
#     'accelererar': 'a-form',
#     'accelereras': 'a-form',
#     'accelererat': 'a-form',
#     'accelerering': 'a-form',
#     'accent': 'a-form',
#     'accenten': 'a-form',
#     'accenter': 'a-form',
#     'accentuera': 'a-form',
#     'accentuerad': 'a-form',
#     'accentuerade': 'a-form',
#     'accentuerades': 'a-form',
#     'accentuerar': 'a-form',
#     'accentueras': 'a-form',
#     'accentuerat': 'a-form',
#     'accentuerats': 'a-form',
#     'accentuering': 'a-form',
#     'accept': 'a-form',
#     'acceptabel': 'a-form',
#     'acceptabelt': 'a-form',
#     'acceptabla': 'a-form',
#     'acceptans': 'a-form',
#     'acceptansen': 'a-form',
#     'accepten': 'a-form',
#     'acceptera': 'a-form',
#     'accepterad': 'a-form',
#     'accepterade': 'a-form',
#     'accepterades': 'a-form',
#     'accepterande': 'a-form',
#     'accepterandet': 'a-form',
#     'accepterar': 'a-form',
#     'accepteras': 'a-form',
#     'accepterat': 'a-form',
#     'accepterats': 'a-form',
#     'access': 'a-form',
#     'accessoar': 'a-form',
#     'accessoarer': 'a-form',
#     'accesstjänster': 'a-form',
#     'accis': 'a-form',
#     'accisfri': 'a-form',
#     'accismedel': 'a-form',
#     'accispliktig': 'a-form',
#     'acetat': 'a-form',
#     'acetatsilke': 'a-form',
#     'aceton': 'a-form',
#     'acetylen': 'a-form',
#     'acetylengas': 'a-form',
#     'acetylenlampa': 'a-form',
#     'acetylsalicylsyra': 'a-form',
#     'acevedo': 'a-form',
#     'achilleas': 'a-form',
#     'achim': 'a-form',
#     'achmed': 'a-form',
#     'achour': 'a-form',
#     'achrén': 'a-form',
#     'achteenberg': 'a-form',
#     'achtenberg': 'a-form',
#     'achtman': 'a-form',
#     'aciditet': 'a-form',
#     'ack': 'a-form',
#     'ackalin': 'a-form',
#     'ackberger': 'a-form',
#     'acke': 'a-form',
#     'ackeberg': 'a-form',
#     'ackebjer': 'a-form',
#     'ackebo': 'a-form',
#     'ackeborn': 'a-form',
#     'ackebrink': 'a-form',
#     'ackeby': 'a-form',
#     'ackedahl': 'a-form',
#     'ackefelt': 'a-form',
#     'ackefjord': 'a-form',
#     'ackefors': 'a-form',
#     'ackegård': 'a-form',
#     'ackehed': 'a-form',
#     'ackelid': 'a-form',
#     'ackelin': 'a-form',
#     'ackelind': 'a-form',
#     'ackell': 'a-form',
#     'ackelman': 'a-form',
#     'ackelöv': 'a-form',
#     'ackemalm': 'a-form',
#     'ackemar': 'a-form',
#     'ackemark': 'a-form',
#     'ackemo': 'a-form',
#     'ackenäs': 'a-form',
#     'ackerberg': 'a-form',
#     'ackerblad': 'a-form',
#     'ackerborg': 'a-form',
#     'ackerby': 'a-form',
#     'ackerdahl': 'a-form',
#     'ackerdal': 'a-form',
#     'ackered': 'a-form',
#     'ackerfeldt': 'a-form',
#     'ackerfors': 'a-form',
#     'ackerhans': 'a-form',
#     'ackerholm': 'a-form',
#     'ackerholt': 'a-form',
#     'ackerhus': 'a-form',
#     'ackerman': 'a-form',
#     'ackermann': 'a-form',
#     'ackermark': 'a-form',
#     'ackerot': 'a-form',
#     'ackers': 'a-form',
#     'ackerstedt': 'a-form',
#     'ackerstierna': 'a-form',
#     'ackerstig': 'a-form',
#     'ackerstrand': 'a-form',
#     'ackerud': 'a-form',
#     'ackerup': 'a-form',
#     'ackeryd': 'a-form',
#     'ackesjö': 'a-form',
#     'ackeskog': 'a-form',
#     'ackesten': 'a-form',
#     'ackestig': 'a-form',
#     'ackeström': 'a-form',
#     'ackeståhl': 'a-form',
#     'ackestål': 'a-form',
#     'acketoft': 'a-form',
#     'ackevall': 'a-form',
#     'ackevik': 'a-form',
#     'ackewald': 'a-form',
#     'ackfeldt': 'a-form',
#     'ackfjäll': 'a-form',
#     'ackfjärd': 'a-form',
#     'ackhammar': 'a-form',
#     'ackheden': 'a-form',
#     'acki': 'a-form',
#     'acking': 'a-form',
#     'ackinger': 'a-form',
#     'ackja': 'a-form',
#     'ackjan': 'a-form',
#     'ackjefärd': 'a-form',
#     'acklamation': 'a-form',
#     'acklamationsval': 'a-form',
#     'ackland': 'a-form',
#     'acklid': 'a-form',
#     'acklimatisera': 'a-form',
#     'acklimatiserat': 'a-form',
#     'acklimatisering': 'a-form',
#     'acklin': 'a-form',
#     'ackling': 'a-form',
#     'acklingavägen': 'a-form',
#     'acklund': 'a-form',
#     'acklén': 'a-form',
#     'ackman': 'a-form',
#     'ackmark': 'a-form',
#     'ackommodation': 'a-form',
#     'ackommodationsförmåga': 'a-form',
#     'ackommodera': 'a-form',
#     'ackommodering': 'a-form',
#     'ackompanjatris': 'a-form',
#     'ackompanjatör': 'a-form',
#     'ackompanjemang': 'a-form',
#     'ackompanjemanget': 'a-form',
#     'ackompanjemangsinstrument': 'a-form',
#     'ackompanjera': 'a-form',
#     'ackompanjerad': 'a-form',
#     'ackompanjerade': 'a-form',
#     'ackompanjerades': 'a-form',
#     'ackompanjerande': 'a-form',
#     'ackompanjerar': 'a-form',
#     'ackompanjeras': 'a-form',
#     'ackompanjerat': 'a-form',
#     'ackompanjering': 'a-form',
#     'ackonius': 'a-form',
#     'ackord': 'a-form',
#     'ackordcentralen': 'a-form',
#     'ackorden': 'a-form',
#     'ackordet': 'a-form',
#     'ackordföljd': 'a-form',
#     'ackordisk': 'a-form',
#     'ackordsarbete': 'a-form',
#     'ackordsberäkn.': 'a-form',
#     'ackordsberäknare': 'a-form',
#     'ackordscentralen': 'a-form',
#     'ackordscentralens': 'a-form',
#     'ackordsförhandling': 'a-form',
#     'ackordshets': 'a-form',
#     'ackordsjobb': 'a-form',
#     'ackordsuppgörelse': 'a-form',
#     'ackreditera': 'a-form',
#     'ackrediterad': 'a-form',
#     'ackrediterade': 'a-form',
#     'ackreditering': 'a-form',
#     'ackrell': 'a-form',
#     'ackring': 'a-form',
#     'acktjärnsgatan': 'a-form',
#     'ackumulation': 'a-form',
#     'ackumulativ': 'a-form',
#     'ackumulatorer': 'a-form',
#     'ackumulera': 'a-form',
#     'ackumulerad': 'a-form',
#     'ackumulerade': 'a-form',
#     'ackumuleras': 'a-form',
#     'ackumulerat': 'a-form',
#     'ackurat': 'a-form',
#     'ackuratess': 'a-form',
#     'ackusativisk': 'a-form',
#     'ackuschörska': 'a-form',
#     'ackvirera': 'a-form',
#     'ackvirering': 'a-form',
#     'ackvis:r': 'a-form',
#     'ackvisition': 'a-form',
#     'ackvisitör': 'a-form',
#     'ackzell': 'a-form',
#     'ackzén': 'a-form',
#     'ackås': 'a-form',
#     'ackér': 'a-form',
#     'acne': 'a-form',
#     'aco': 'a-form',
#     'acosta': 'a-form',
#     'acryl': 'a-form',
#     'acs': 'a-form',
#     'action': 'a-form',
#     'actionfilm': 'a-form',
#     'actionfilmen': 'a-form',
#     'actionfilmer': 'a-form',
#     'actionhistoria': 'a-form',
#     'actionhjälten': 'a-form',
#     'actionkomedi': 'a-form',
#     'actionkomedier': 'a-form',
#     'actionscener': 'a-form',
#     'actionserie': 'a-form',
#     'actionsurf': 'a-form',
#     'acuna': 'a-form',
#     'ada': 'a-form',
#     'adagio': 'a-form',
#     'adak': 'a-form',
#     'adaktusson': 'a-form',
#     'adakvägen': 'a-form',
#     'adalbert': 'a-form',
#     'adalberth': 'a-form',
#     'adam': 'a-form',
#     'adama': 'a-form',
#     'adamczyk': 'a-form',
#     'adamek': 'a-form',
#     'adami': 'a-form',
#     'adamovic': 'a-form',
#     'adams': 'a-form',
#     'adams_väg': 'a-form',
#     'adamsdräkt': 'a-form',
#     'adamsen': 'a-form',
#     'adamsgatan': 'a-form',
#     'adamson': 'a-form',
#     'adamsson': 'a-form',
#     'adamstorpsvägen': 'a-form',
#     'adamsvägen': 'a-form',
#     'adamsäpple': 'a-form',
#     'adamsäpplet': 'a-form',
#     'adamzon': 'a-form',
#     'adan': 'a-form',
#     'adaptation': 'a-form',
#     'adapter': 'a-form',
#     'adaptera': 'a-form',
#     'adaptering': 'a-form',
#     'adaption': 'a-form',
#     'adaptiv': 'a-form',
#     'adaptiva': 'a-form',
#     'adar': 'a-form',
#     'adare': 'a-form',
#     'adauktusson': 'a-form',
#     'adawi': 'a-form',
#     'adb': 'a-form',
#     'adb-avtal': 'a-form',
#     'adb-chef': 'a-form',
#     'adb-enhet': 'a-form',
#     'adb-enheten': 'a-form',
#     'adb-enhetens': 'a-form',
#     'adb-funktionen': 'a-form',
#     'adb-funktionens': 'a-form',
#     'adb-gruppen': 'a-form',
#     'adb-kons.': 'a-form',
#     'adb-konsult': 'a-form',
#     'adb-kontoret': 'a-form',
#     'adb-kontorets': 'a-form',
#     'adb-man': 'a-form',
#     'adb-samordnarutbildning': 'a-form',
#     'adb-samordnarutbildningen': 'a-form',
#     'adb-system': 'a-form',
#     'adb-tekn.': 'a-form',
#     'adb-tekniker': 'a-form',
#     'adb-upptagningar': 'a-form',
#     'adberg': 'a-form',
#     'adbo': 'a-form',
#     'adborn': 'a-form',
#     'adbring': 'a-form',
#     'adbro': 'a-form',
#     'adbåge': 'a-form',
#     'addberger': 'a-form',
#     'addby': 'a-form',
#     'adde': 'a-form',
#     'addemark': 'a-form',
#     'addera': 'a-form',
#     'adderar': 'a-form',
#     'adderas': 'a-form',
#     'adderat': 'a-form',
#     'addering': 'a-form',
#     'addi': 'a-form',
#     'addie': 'a-form',
#     'addiktion': 'a-form',
#     'addin': 'a-form',
#     'adding': 'a-form',
#     'addison': 'a-form',
#     'addition': 'a-form',
#     'addukt': 'a-form',
#     'adduktion': 'a-form',
#     'addy': 'a-form',
#     'addén': 'a-form',
#     'ade': 'a-form',
#     'adebahr': 'a-form',
#     'adeberg': 'a-form',
#     'adebjörk': 'a-form',
#     'adebo': 'a-form',
#     'adeborg': 'a-form',
#     'adeborn': 'a-form',
#     'adebrant': 'a-form',
#     'adebratt': 'a-form',
#     'adebring': 'a-form',
#     'adebrink': 'a-form',
#     'adebro': 'a-form',
#     'adeby': 'a-form',
#     'adebäck': 'a-form',
#     'adebåge': 'a-form',
#     'adeen': 'a-form',
#     'adefalk': 'a-form',
#     'adefelt': 'a-form',
#     'adefjord': 'a-form',
#     'adefjärd': 'a-form',
#     'adefors': 'a-form',
#     'adegren': 'a-form',
#     'adegård': 'a-form',
#     'adehed': 'a-form',
#     'adeheimer': 'a-form',
#     'adeholm': 'a-form',
#     'adehorn': 'a-form',
#     'adehög': 'a-form',
#     'adeklint': 'a-form',
#     'adekvans': 'a-form',
#     'adekvat': 'a-form',
#     'adekvata': 'a-form',
#     'adel': 'a-form',
#     'adela': 'a-form',
#     'adelaide': 'a-form',
#     'adeland': 'a-form',
#     'adelavägen': 'a-form',
#     'adelback': 'a-form',
#     'adelbjer': 'a-form',
#     'adelborg': 'a-form',
#     'adelborgsvägen': 'a-form',
#     'adelbrand': 'a-form',
#     'adelbrant': 'a-form',
#     'adelbratt': 'a-form',
#     'adelby': 'a-form',
#     'adelbäck': 'a-form',
#     'adeldal': 'a-form',
#     'adele': 'a-form',
#     'adelfalk': 'a-form',
#     'adelgatan': 'a-form',
#     'adelgren': 'a-form',
#     'adelgård': 'a-form',
#     'adelhag': 'a-form',
#     'adelhammar': 'a-form',
#     'adelhed': 'a-form',
#     'adelheid': 'a-form',
#     'adelia': 'a-form',
#     'adelin': 'a-form',
#     'adelina': 'a-form',
#     'adelind': 'a-form',
#     'adeline': 'a-form',
#     'adelius': 'a-form',
#     'adeljung': 'a-form',
#     'adell': 'a-form',
#     'adelman': 'a-form',
#     'adelmar': 'a-form',
#     'adelmyr': 'a-form',
#     'adeln': 'a-form',
#     'adelns': 'a-form',
#     'adelros': 'a-form',
#     'adelrydh': 'a-form',
#     'adelsberg': 'a-form',
#     'adelsberger': 'a-form',
#     'adelsbergsvägen': 'a-form',
#     'adelsdam': 'a-form',
#     'adelsdottern': 'a-form',
#     'adelsfamilj': 'a-form',
#     'adelsgatan': 'a-form',
#     'adelsgård': 'a-form',
#     'adelsjö': 'a-form',
#     'adelskalendern': 'a-form',
#     'adelskap': 'a-form',
#     'adelskapet': 'a-form',
#     'adelskogh': 'a-form',
#     'adelsköld': 'a-form',
#     'adelsköldsgatan': 'a-form',
#     'adelsman': 'a-form',
#     'adelsmannen': 'a-form',
#     'adelsmannens': 'a-form',
#     'adelsmans': 'a-form',
#     'adelsmark': 'a-form',
#     'adelsmän': 'a-form',
#     'adelsmännen': 'a-form',
#     'adelsmärke': 'a-form',
#     'adelsnäs': 'a-form',
#     'adelsnäsvägen': 'a-form',
#     'adelsohn': 'a-form',
#     'adelson': 'a-form',
#     'adelsson': 'a-form',
#     'adelstam': 'a-form',
#     'adelsten': 'a-form',
#     'adelstitel': 'a-form',
#     'adelstokige': 'a-form',
#     'adelstorpsvägen': 'a-form',
#     'adelstrand': 'a-form',
#     'adelståhl': 'a-form',
#     'adelstål': 'a-form',
#     'adelsund': 'a-form',
#     'adelsvälde': 'a-form',
#     'adelsvärd': 'a-form',
#     'adelswärd': 'a-form',
#     'adelswärdsgatan': 'a-form',
#     'adelswärdsvägen': 'a-form',
#     'adelsö': 'a-form',
#     'adelsögatan': 'a-form',
#     'adelé': 'a-form',
#     'adelöf': 'a-form',
#     'adelöv': 'a-form',
#     'adelövägen': 'a-form',
#     'adelöw': 'a-form',
#     'adem': 'a-form',
#     'ademaj': 'a-form',
#     'ademan': 'a-form',
#     'ademar': 'a-form',
#     'ademark': 'a-form',
#     'ademi': 'a-form',
#     'ademyr': 'a-form',
#     'aden': 'a-form',
#     'adenauer': 'a-form',
#     'adenberg': 'a-form',
#     'adenborg': 'a-form',
#     'adenbrandt': 'a-form',
#     'adenbrant': 'a-form',
#     'adenbring': 'a-form',
#     'adenby': 'a-form',
#     'adenbäck': 'a-form',
#     'adenfalk': 'a-form',
#     'adenfelt': 'a-form',
#     'adenfors': 'a-form',
#     'adengård': 'a-form',
#     'adenholm': 'a-form',
#     'adenius': 'a-form',
#     'adenkrans': 'a-form',
#     'adenkrantz': 'a-form',
#     'adenling': 'a-form',
#     'adenlöf': 'a-form',
#     'adenmark': 'a-form',
#     'adensjö': 'a-form',
#     'adenskog': 'a-form',
#     'adenstam': 'a-form',
#     'adenstedt': 'a-form',
#     'adenvall': 'a-form',
#     'adenwall': 'a-form',
#     'adenäs': 'a-form',
#     'adenås': 'a-form',
#     'adept': 'a-form',
#     'adepter': 'a-form',
#     'ader': 'a-form',
#     'aderby': 'a-form',
#     'aderfelt': 'a-form',
#     'aderfors': 'a-form',
#     'aderheim': 'a-form',
#     'aderklint': 'a-form',
#     'aderlind': 'a-form',
#     'aderling': 'a-form',
#     'aderlund': 'a-form',
#     'adermalm': 'a-form',
#     'aderman': 'a-form',
#     'adermark': 'a-form',
#     'aderot': 'a-form',
#     'aderoth': 'a-form',
#     'adersjö': 'a-form',
#     'aderskog': 'a-form',
#     'aderstedt': 'a-form',
#     'adersten': 'a-form',
#     'aderstål': 'a-form',
#     'aderth': 'a-form',
#     'aderton': 'a-form',
#     ...}})]

# %%
[x[0] for x in res]
# Out:
# [('models/deep-phonemizer-se.pt',),
#  ('models/DeepPhon/winhome/Downloads/DeepPhon_to_send/best_model.pt',),
#  ('models/DeepPhon/winhome/Downloads/DeepPhon_to_send/model_step_40k.pt',)]

# %%
print([(x[0],x[1]["accuracy"]) for x in res])
with open("output/phonemizer_eval_res", "wb") as f:
    pickle.dump(res,f)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 12>()
#       7 kwargs= {
#       8     "device" : "cuda",
#       9     "stub" : True
#      10 }
#      11 res = grid(phonemizer_eval, model_paths, stub=True)
# ---> 12 print([(x[0],x[1]["accuracy"]) for x in res])
#      13 with open("output/phonemizer_eval_res", "wb") as f:
#      14     pickle.dump(res,f)
#
# Input In [12], in <listcomp>(.0)
#       7 kwargs= {
#       8     "device" : "cuda",
#       9     "stub" : True
#      10 }
#      11 res = grid(phonemizer_eval, model_paths, stub=True)
# ---> 12 print([(x[0],x[1]["accuracy"]) for x in res])
#      13 with open("output/phonemizer_eval_res", "wb") as f:
#      14     pickle.dump(res,f)
#
# KeyError: 'accuracy'

# %% [markdown]
# ### Analysis of data

# %%
with open("output/phonemizer_eval_res", "rb") as f:
    res = pickle.load(f)

model2word2pred = {x[0][0]: x[1]["output_dict"] for x in res} #DD

models = ["deepphon", "bestmodel", "model40k"]
ids = ["deep-p", "best_model" , "model_step_40k"]
def key_translator(x):
    mask = [id_i in x for id_i in ids]
    return models[mask.index(True)]

model2word2pred = { key_translator(k) : v for k,v in model2word2pred.items()}

true_dict = read_phoneme_dict("models/stress_lex_mtm.txt")

model2word2pred["correct"] = {k : "".join(v) for k,v in true_dict.items()}


word2model2pred = { word : {model : model2word2pred[model][word] for model in model2word2pred} for word in model2word2pred["correct"]}

def filter_phonemizer_predictions(word2model2pred, deepphoncorrect, bestmodelcorrect, model40kcorrect):
    result = {}
    mask = [deepphoncorrect, bestmodelcorrect, model40kcorrect]
    for word, model2pred in word2model2pred.items():
        mask_value= [model2pred["deepphon"] == model2pred["correct"],
                     model2pred["bestmodel"] == model2pred["correct"],
                     model2pred["model40k"] == model2pred["correct"]
                    ]
        if mask_value == mask:
            result[word] = model2pred
    return {"result" : result}

# %%
args = [
    [word2model2pred],
    [True,False],
    [True,False],
    [True,False]
]
res = grid(filter_phonemizer_predictions, args, {}, stub=False)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# deepphon correct bestmodel correct 
import random
random.seed(0)
for x in res:
    print("=========================")
    print("deephon correct, bestmodel orrect, 40k correct")
    print(x[0][1:])
    print("Count of filter: ", len(x[1]["result"]))
    print("Percentage: ", len(x[1]["result"])/ sum([ len(x[1]["result"]) for x in res]))
    # Draw 5 samples from each category
    words_sample = random.sample(x[1]["result"].keys(), k=5)
    for word in words_sample:
        print(word, x[1]["result"][word]["correct"] ,x[1]["result"][word]["deepphon"],x[1]["result"][word]["bestmodel"], x[1]["result"][word]["model40k"], sep=" | ")
    print("words sample: ", words_sample)
print("Sum of counts :", sum([ len(x[1]["result"]) for x in res]))
print("Length of dict: ", len(word2model2pred))
# Out:
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (True, True, True)
# Count of filter:  169341
# Percentage:  0.4840540934544176
# nordebrand | n"o2:rdebr`and | n"o2:rdebr`and | n"o2:rdebr`and | n"o2:rdebr`and
# priskänslig | pr"i2:stj'enslig | pr"i2:stj'enslig | pr"i2:stj'enslig | pr"i2:stj'enslig
# beboelig | beb'o2:elig | beb'o2:elig | beb'o2:elig | beb'o2:elig
# jangberg | j"angb`ä3rj | j"angb`ä3rj | j"angb`ä3rj | j"angb`ä3rj
# staller | st'alër | st'alër | st'alër | st'alër
# words sample:  ['nordebrand', 'priskänslig', 'beboelig', 'jangberg', 'staller']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (True, True, False)
# Count of filter:  27224
# Percentage:  0.07781865372356998
# milutinovic | milutin'å2:vittj | milutin'å2:vittj | milutin'å2:vittj | milut'i2:nåvittj
# krönlind | kr"ö2:nl`ind | kr"ö2:nl`ind | kr"ö2:nl`ind | kr"ö2:nl'ind
# vimlet | v'imlët | v'imlët | v'imlët | v"imlët
# översköterska | "ö2:vërsj`ö2:terska | "ö2:vërsj`ö2:terska | "ö2:vërsj`ö2:terska | "ö2:versj`ö2:terska
# hovegård | h"å2:veg`å2:rd | h"å2:veg`å2:rd | h"å2:veg`å2:rd | h"o2:veg`å2:rd
# words sample:  ['milutinovic', 'krönlind', 'vimlet', 'översköterska', 'hovegård']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (True, False, True)
# Count of filter:  11138
# Percentage:  0.03183750239395836
# riken | r"i2:kën | r"i2:kën | r'i2:kën | r"i2:kën
# luftbombardemang | l"uftbåmbardem'ang | l"uftbåmbardem'ang | l"uftbombardem'ang | l"uftbåmbardem'ang
# terek | t"e2:r`e2:k | t"e2:r`e2:k | t'e2:rëk | t"e2:r`e2:k
# hallbe | h"albë | h"albë | h"alb`e2: | h"albë
# sebahat | sebah'at | sebah'at | sebah'a2:t | sebah'at
# words sample:  ['riken', 'luftbombardemang', 'terek', 'hallbe', 'sebahat']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (True, False, False)
# Count of filter:  57569
# Percentage:  0.1645585540777329
# dröjsmålet | dr"öjsm`å2:lët | dr"öjsm`å2:lët | dr"öjsm'å2:lët | dr"öjsm'å2:lët
# hinderson | h'indërsån | h'indërsån | h"indërsån | h"indërsån
# dubbelexponering | d"ubëlekspån`e2:ring | d"ubëlekspån`e2:ring | d"ubëlekspån'e2:ring | d"ubëlekspån'e2:ring
# tjänstebilen | tj"ensteb`i2:lën | tj"ensteb`i2:lën | tj"ensteb'i2:lën | tj"ensteb'i2:lën
# brishagen | br"i2:sh`a2:gën | br"i2:sh`a2:gën | br"i2:sh'a2:gën | br"i2:sh`agën
# words sample:  ['dröjsmålet', 'hinderson', 'dubbelexponering', 'tjänstebilen', 'brishagen']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (False, True, True)
# Count of filter:  10892
# Percentage:  0.03113432178802249
# varukännedom | v"a2:rutjened'om | v"a2:rutj"ened'om | v"a2:rutjened'om | v"a2:rutjened'om
# infiltratörer | infiltrat'ö3rër | "infiltrat'ö3rër | infiltrat'ö3rër | infiltrat'ö3rër
# solidariteten | solidarit'e2:tën | so2lidarit'e2:tën | solidarit'e2:tën | solidarit'e2:tën
# törnestorpsvägen | t"ö3rnëstårpsv`ä2:gën | t"ö3rnestårpsv`ä2:gën | t"ö3rnëstårpsv`ä2:gën | t"ö3rnëstårpsv`ä2:gën
# fetmar | f"etmar | f'e2:tmar | f"etmar | f"etmar
# words sample:  ['varukännedom', 'infiltratörer', 'solidariteten', 'törnestorpsvägen', 'fetmar']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (False, True, False)
# Count of filter:  8352
# Percentage:  0.023873839108847213
# nöter | n'ö2:tër | n"ö2:tër | n'ö2:tër | n"ö2:tër
# entusiasmerats | angtusiasm'e2:rats | antusiasm'e2:rats | angtusiasm'e2:rats | "e2:ntu2:siasmer'ats
# dalarve | d"a2:l`arvë | d"a2:l'arvë | d"a2:l`arvë | d"a2:l'arvë
# pjäsbacken | pj"ä2:sb`akën | pj"ä2:sb'akën | pj"ä2:sb`akën | pj"ä2:sb'akën
# vangstad | v"angst`a2:d | v"angst'a2:d | v"angst`a2:d | v"a2:ngst`a2:d
# words sample:  ['nöter', 'entusiasmerats', 'dalarve', 'pjäsbacken', 'vangstad']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (False, False, True)
# Count of filter:  4099
# Percentage:  0.011716818307850183
# feminin | femin'i2:n | f"e2:m'i2:nin | f"e2:m'i2:nin | femin'i2:n
# rundviksvägen | r"undvi2:ksv'ä2:gën | r"undvi2:ksv`ä2:gën | r"undvi2:ksv`ä2:gën | r"undvi2:ksv'ä2:gën
# tidsbegrepp | t"i2:dsbegr`ep | t"i2:dsbegr'ep | t"i2:dsbegr'ep | t"i2:dsbegr`ep
# persborgstorget | p"ä3:rsbårjst`årjët | p"ä3:rsbårjst'årjët | p"ä3:rsbårjst'årjët | p"ä3:rsbårjst`årjët
# keita | k'ejta | k"ejta | k'ajta | k'ejta
# words sample:  ['feminin', 'rundviksvägen', 'tidsbegrepp', 'persborgstorget', 'keita']
# =========================
# deephon correct, bestmodel orrect, 40k correct
# (False, False, False)
# Count of filter:  61224
# Percentage:  0.17500621714560127
# oknytt | åk"ejn'yt | "o2:kn`yt | "o2:kn'yt | "o2:kn'yt
# marknära | m"arkn`ä3:ra | m"arkn'ä3:ra | m"arkn'ä3:ra | m"arkn'ä3:ra
# linjeförm. | l"injefö3rm`an | l"injef'ö3rm. | l"injef'ö3rm. | l"injefö3rm.
# vapenmekaniker | v"a2:pënmek`a2:nikër | v"a2:pënmek'a2:nikër | v"a2:pënmek'a2:nikër | v"a2:pënmek'a2:nikër
# naturbarn | nat"u2:rb`a2:rn | nat"u2:rb'a2:rn | nat"u2:rb'a2:rn | nat"u2:rb'a2:rn
# words sample:  ['oknytt', 'marknära', 'linjeförm.', 'vapenmekaniker', 'naturbarn']
# Sum of counts : 349839
# Length of dict:  349839

# %% [markdown]
# ## Parameterized agreement
#
# We relax the notion of agreement and we consider that KB and Google agree only when their lcs is over a percentage of their maximum length. We then consider that in cases of agreement we keep only the largest common subsequence (LCS) of the two as the prediction.
#
# In the following cells we test this for different threshhold levels, we produce first the WERs per threshold level and also the percentage of utterances where there is agreement

# %%
experiment = parameterized_agreement
kwargs = {
    "_filter": None, 
    "phoneme_words" : False,
    "singular_phonemes" : False,
    "preprocess_hook" : None,
    "stress_marks" : True,
    "trusted_model" : "kb",
    "threshold_range" : (0,1)
}
res = experiment(bunches, "models/deep-phonemizer-se.pt", **kwargs)

# %%
x = res["threshold_levels"]
y = res["agreement_wers"]

plt.figure(figsize=(10, 6), dpi=80)

plt.xticks(np.arange(min(x), max(x)+1, 0.1))
plt.plot(x, [yi * 100 for yi in y ])

# %%
#fig, ax1 = plt.subplots()

#ax2 = ax1.twinx()
#ax2.set_ylim(0,100)
x = res["threshold_levels"]
y = res["agreement_ratios"]

plt.figure(figsize=(10, 6), dpi=80)

plt.xticks(np.arange(min(x), max(x)+1, 0.1))
plt.plot(x, [yi * 100 for yi in y ], "r")
#ax2.plot(res["threshold_levels"], [x * 100 for x in res["agreement_ratios"]], "r")
#plt.plot(res["threshold_levels"], [x * 10 for x in res["ensemble_wers"]])

# %% [markdown]
# ## Pairwise evaluation
#
# Here we test KB and Google, calculating their WERs under different scenarios (words, phoneme_words, singular phonemes) and also statistics percentages about
# agreement, overlap and mean-lcs

# %%
experiment = meval
_filter = {
    "agreement" : False,
    "g_correct" : False,
    "kb_correct" : False,
}
kwargs = {
    "_filter": None, 
    "phoneme_words" : False,
    "singular_phonemes" : False,
    "preprocess_hook" : None,
    "stress_marks" : True
}
res = experiment_repeats(experiment, 5, bunches, "./models/deep-phonemizer-se.pt", **kwargs)
print_experiment_report(res)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# agreement: 0.44250093040565686±0.0
# g_correct_kb_not : 0.24632843791722298±0.0
# kb_correct_g_not : 0.3704939919893191±0.0
# agreement_not_correct: 0.028595458368376788±0.0
# both_incorrect_disagreement: 0.38317757009345793±0.0
# google_wer: 0.13522388059701493±0.0
# kb_wer: 0.08686567164179104±0.0
# google-avg-length: 7.212132489765538±0.0
# correct-avg-length: 7.480461481205806±0.0
# kb-avg-length: 7.477112020841087±0.0
# lcs-mean: 0.8311098882842709±0.0
# error_index_overlap: 0.1622994652406417±0.0

# %% [markdown]
# ## The Google Shortening Detector
#
# Google's ASR sometimes outputs nothing especially at the start of sentences. Try detecting that by comparing the sequences of vowels

# %%
vowels = set("aeiouåäö")
def the_shortening_happened(bunch, threshold):
    numbers = set("0123456789")
    if len(bunch["google"]) > len(bunch["kb"]):
        return False
    for x in bunch["google"]:
        if x in numbers:
            return False
    google_out = [x for x in bunch["google"] if x in vowels]
    kb_out = [x for x in bunch["kb"] if x in vowels]
    score = SequenceMatcher(None, google_out, kb_out).ratio()
    return score < threshold and score > 0.2
    
bunch_list = [{k: bunches[k][i] for k in bunches} for i in range(len([x for x in bunches.values()][0]))]
sorted_bunch_list = [x for x in bunch_list if the_shortening_happened(x, 0.6)]

# %%
print("Length of the bunch list" , len(bunch_list))
print("Shortened bunches" ,  len(sorted_bunch_list))
print("The shortening percentage: ", len(sorted_bunch_list) / len(bunch_list))
# Out:
# Length of the bunch list 911
# Shortened bunches 18
# The shortening percentage:  0.019758507135016465

# %%
sorted_bunch_list
# Out:
# [{'google': 'var en bra roll för',
#   'correct': 'var den bra då i alla fall',
#   'kb': 'var de en bra rål fall'},
#  {'google': 'eller',
#   'correct': 'oj då såg ni alla i går eller',
#   'kb': 'ojdå såg ni alla higår eller'},
#  {'google': 'djävulen', 'correct': 'är väl en', 'kb': 'a är vä en'},
#  {'google': 'bra det där',
#   'correct': 'kanske blir rätt så bra det där och',
#   'kb': 'så blir rett så bra det där och'},
#  {'google': 'faktiskt',
#   'correct': 'det är det faktiskt',
#   'kb': 'det är det faktiskt'},
#  {'google': 'förslag på',
#   'correct': 'dom är vi uschliga på',
#   'kb': 'de är vi uörsliga på'},
#  {'google': 'så att i så fall är',
#   'correct': 'undrar om det kan ha vart så att i så fall är',
#   'kb': 'vi undra om det kan ha vart så att det i så fall är'},
#  {'google': 'nej precis',
#   'correct': 'nej det var kanske på slutet precis',
#   'kb': 'nej det var kanske på slutet precis'},
#  {'google': 'nej', 'correct': 'nä det förs', 'kb': 'nä det först'},
#  {'google': 'kanske någon annan ensam blå',
#   'correct': 'ja han har ju haft ett par dom är kanske i vad nån sån här böå han hade en sån här blå',
#   'kb': 'jhan har ju haft ett par de är kanske i vad någn san ä blå jagföhan har den sär blå'},
#  {'google': 'vattnet',
#   'correct': 'ända nere vid vattnet',
#   'kb': 'ända ner vid vattnet'},
#  {'google': 'den där',
#   'correct': 'till exempel den dära',
#   'kb': 'ill exempel den dära'},
#  {'google': 'rättvik kaffe',
#   'correct': 'jättemycket kaffebröd',
#   'kb': 'jättemycket kaffe präat'},
#  {'google': 'actionfilm',
#   'correct': 'ja nu blir det kanske sån här actionfilm',
#   'kb': 'ha nu blir det kanske s actionfilm'},
#  {'google': 'maxi med', 'correct': 'ja mats är med', 'kb': 'ja maxe med'},
#  {'google': 'polens badplats',
#   'correct': 'vi har badat i ho vid holens badplats',
#   'kb': 'v har badig till ho vid holens badplats'},
#  {'google': 'fint',
#   'correct': 'ja det är litet men fint',
#   'kb': 'na det är litet vör fint'},
#  {'google': 'nya stället mats eller ordning',
#   'correct': 'vi gör så rätt mats håller ordning',
#   'kb': 'vi gör så rätt mats håller ordning'}]

# %%
random.sample(sorted_bunch_list, k=5)
# Out:
# [{'google': 'oj då', 'correct': 'oj då', 'kb': 'åjda'},
#  {'google': 'det är liksom', 'correct': 'det är liksom', 'kb': 'da r liksom'},
#  {'google': 'nej', 'correct': 'nä det förs', 'kb': 'nä det först'},
#  {'google': 'den där',
#   'correct': 'till exempel den dära',
#   'kb': 'ill exempel den dära'},
#  {'google': 'ja det är inte',
#   'correct': 'ja ja det ser inte',
#   'kb': 'ja ja dent'}]

# %% [markdown]
# # Error analysis

# %% [markdown]
# ### Sort sentences based on WER

# %%
def bunch_normalized_wer(bunch, model):
    return wer(bunch["correct"], bunch[model]) * len(bunch["correct"].split())

def metric(x):
    return bunch_normalized_wer(x,"google")

bunch_list = [{k: bunches[k][i] for k in bunches} for i in range(len([x for x in bunches.values()][0]))]


for bunch in bunch_list:
    bunch["ensemble"] = get_ensemble_output(bunch, None, 0.6, use_phonemizer=False) 
    
sorted_bunch_list = sorted(bunch_list, key=lambda x : metric(x))
sorted_bunch_list.reverse()

# %%
wer_sums =  { k : sum(bunch_normalized_wer(x,k) for x in bunch_list) for k in bunch_list[0]}

# %%
wer_sums
# Out:
# {'google': 2718.0, 'correct': 0.0, 'kb': 1746.0, 'ensemble': 1805.0}

# %%
cbunch = sorted_bunch_list[2]
cbunch
curr_wers = {k : bunch_normalized_wer(cbunch,k) for k,v in cbunch.items()}
curr_wers
# Out:
# {'google': 'en riktigt dålig ser jag 111 234 345 456',
#  'correct': 'en riktigt dålig ser jag ett elva två tretti fyra tre fyrtio fem fyra femti sex',
#  'kb': 'en riktigt dålig serjag ett elva två trettiofyra tre fyrtiofem fyrafemtiosex',
#  'ensemble': 'en riktigt dålig serjag ett elva två trettiofyra tre fyrtiofem fyrafemtiosex'}
# {'google': 11.0, 'correct': 0.0, 'kb': 9.0, 'ensemble': 9.0}

# %%
ls = []
models = ["google", "kb", "ensemble"]
for model in models:
    l = []
    sorted_bunch_list = sorted(bunch_list, key=lambda x : bunch_normalized_wer(x,model))
    sorted_bunch_list.reverse()
    for x in sorted_bunch_list:
        curr_wers = {k : bunch_normalized_wer(x,k) for k,v in x.items()}
        l.append(curr_wers[model])
    ls.append(l)
    
labels = models
colors = "rgb"

for i, l in enumerate(ls):
    plt.plot(l, colors[i], label=labels[i])
    plt.legend()

# %%
l = []
model = "google"
sorted_bunch_list = sorted(bunch_list, key=lambda x : bunch_normalized_wer(x,"google") - bunch_normalized_wer(x,"kb"))
sorted_bunch_list.reverse()
for x in sorted_bunch_list:
    l.append(bunch_normalized_wer(x,"google") - bunch_normalized_wer(x,"kb"))
plt.plot(l)

# %%
plt.plot(l)

# %%
plt.plot(l)

# %%
plt.plot(l)

# %%
get_kb_google_unmatched_blocks(cbunch)
# Out:
# [('det', 'nego'),
#  ('johan sådär', 'är ju han så där att'),
#  ('jag hoppas inte', 'ju han på sånt där'),
#  ('isolera du', 'isolerade och'),
#  ('det', '')]

# %% [markdown]
# # Visualization

# %%
idx = 43
size = 10
def get_triad(idx, bunch):
    #### Google, correct, Kb
    return bunch[0][idx], bunch[1][idx], bunch[2][idx]

def plot_triad(triad,ax):
    ax.text(0.0, 0.0, triad[0], size=size, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.8, 0.8),
                       )
             )

    ax.text(0, -2.5,  triad[2], size=size, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(153/255, 51/255, 0/255),
                       fc=(255/255, 153/255, 102/255),
                       )
             )
    ax.text(0, -5,  triad[1], size=size, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(42 / 255, 162 / 255, 42 / 255),
                       fc=(133 / 255, 224 / 255, 133 / 255),
                       )
             )
    
    ax.set_ylim(-10, 10)
    ax.set_xlim(-10, 10)

# %%
fig, axs = plt.subplots(1,2, figsize=(15, 5))
idx = 0
plot_triad(get_triad(idx, text_data_bunch) ,axs[0])
plot_triad(get_triad(idx, phoneme_data_bunch) ,axs[1])

# %%
def print_triad_correctness(triad):
    #### Google, correct, Kb
    print("Google correct ", triad[1] == triad[0])
    print("KB correct ", triad[1] == triad[2])
    print("Agreement ", triad[0] == triad[2])
    
    print("Google WER ", wer(triad[1], triad[0]))
    print("KB WER ", wer(triad[1], triad[2]))
